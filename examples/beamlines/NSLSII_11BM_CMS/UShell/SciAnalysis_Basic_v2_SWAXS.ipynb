# %% [markdown]
# # Data analysis with SciAnalysis
#
# last updated: 2024 Jan
#
# In this notebook, we can load the raw tiff, load or extract metedata, analysis the data, save the analysis results and metadata in .H5.
#
# --------------------------------------
#
# *exp.dict*: The experiment dictionary. 'Experiment' is a series of measurements, e.g. in-situ thermal annealing measurements of a sample.
#
#
# --------------------------------------

# %% [markdown]
# # &#9635; SciAnalysis for Experiment
#
# At home insitute, download SciAnalysis at: https://github.com/CFN-softbio/SciAnalysis

# %%
#%matplotlib nbagg
# Imports
########################################
import sys, os, time, glob, imageio, datetime, pprint, math
import sqlite3
import pandas as pd
from silx.io.dictdump import dicttoh5, h5todict

SciAnalysis_PATH='/nsls2/data/cms/legacy/xf11bm/software/SciAnalysis/' ### Specify this
SciAnalysis_PATH in sys.path or sys.path.append(SciAnalysis_PATH)

from SciAnalysis import tools
from SciAnalysis.XSAnalysis.Data import *
from SciAnalysis.XSAnalysis import Protocols
from SciAnalysis.ExpAnalysis import Experiment
from SciAnalysis.ExpAnalysis import Tools

now = datetime.datetime.now()
dt_string = now.strftime("%Y/%m/%d %H:%M:%S")
print("{}\n".format(dt_string))

# %pwd
# Out:
# 2024/01/26 16:09:32
# '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo'

# %% [markdown]
# &#9733; __NOTE__
#
# For routine analysis, go to __Section 0__ for calibration and then jump to (__Section 7__ for stitching if needed) __Section 6__ for batch processing
#
# For real-time analysis of series data, go through other sections.

# %% [markdown]
# ## 0. Calibration

# %% [markdown]
# #### __Direct beam__

# %%
EXPR_DIR = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/maxs/'
pattern = '*DirectBeam*'
infiles = glob.glob(os.path.join(EXPR_DIR+'raw/', pattern+'.tiff'))

#infiles = sorted(infiles, key=lambda x: x.split('_saxs')[0].split('_')[-1]) 
print(infiles)

if len(infiles)>0:
    data = Data2DScattering()
    data.load(infiles[-1])
    #data.blur(sigma=1)
    img = data.data
    print('Size = {}'.format(img.shape))

    ## Plot
    # %matplotlib inline
    plt.figure(1); plt.imshow(np.log(img+3)); plt.colorbar()
    beam_center = [np.argmax(np.max(img,0)), np.argmax(np.max(img,1))]
    print('Beam center = {}'.format(beam_center))

    img[beam_center[1], beam_center[0]] = 0
    beam_center = [np.argmax(np.max(img,0)), np.argmax(np.max(img,1))]
    print('Beam center = {}'.format(beam_center))
else:
    print('No matching files found')

# %%
### 
from PIL import Image

folder = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor/waxs/raw/'
filename =  'PureAgBH*'
infile = folder + filename

img = Image.open(infile).convert('I')
img = np.asarray(img).astype(float)

# %matplotlib inline
plt.figure(10, figsize=(12, 12)); plt.clf()
plt.imshow(np.log10(img+3))
plt.colorbar()
plt.title(filename)

## Guess center (and radius)
center = [758, 1078]
radius = 464

# Plot center
plt.plot(center[0], center[1], 'rx')

# Plot circle
for theta in np.arange(360):
    x = center[0] + radius * np.sin(theta/180*np.pi)
    y = center[1] + radius * np.cos(theta/180*np.pi)
    plt.plot(x, y, 'w.', markersize=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 8
#       5 filename =  'PureAgBH*'
#       6 infile = folder + filename
# ----> 8 img = Image.open(infile).convert('I')
#       9 img = np.asarray(img).astype(float)
#      11 get_ipython().run_line_magic('matplotlib', 'inline')
#
# File /nsls2/conda/envs/2023-1.3-py39/lib/python3.9/site-packages/PIL/Image.py:3092, in open(fp, mode, formats)
#    3089     filename = fp
#    3091 if filename:
# -> 3092     fp = builtins.open(filename, "rb")
#    3093     exclusive_fp = True
#    3095 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor/waxs/raw/PureAgBH*'

# %% [markdown]
# #### __&#9733; Calibration AgBH__
#
# Energy, beam center, SD distance
#
# 1. Specify wavelength
# 2. Tweak beam center and SD distance to get the best match for the calibrant
# 3. __For SAXS, make custom mask (in GIMP) to cover up beamstop__

# %%
#EXPR_DIR = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/test/'
EXPR_DIR = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/test3/'
DET = 'maxs'
flag_stitch = 0 #for mask for batch processing

exp = Experiment.experiment('Ag', folder=EXPR_DIR, det=DET, beamline='None') ##Experiment name: rbitrary or related to the sample name
pattern = '*Ag*5.00*'          
        
load_custom_mask = 0
custom_mask = EXPR_DIR+'saxs/analysis/mask.png'


### Specify beam positions, distance, etc
if 'saxs' in DET:
    calibration = Calibration(wavelength_A=0.9184) # 13.5 keV
    calibration.set_image_size(1475, height=1679) # Pilatus2M
    calibration.set_pixel_size(pixel_size_um=172.0)
    calibration.set_beam_position(757-1, 1679-601) # SAXSx -65, SAXSy -73    
    calibration.set_distance(5.065)    
    
    mask_dir = SciAnalysis_PATH + '/SciAnalysis/XSAnalysis/masks/'
    if flag_stitch:
        mask = Mask(mask_dir+'Dectris/Pilatus2M_vertical_gaps-mask.png')
    else:
        mask = Mask(mask_dir+'Dectris/Pilatus2M_gaps-mask.png')

    if load_custom_mask:
        mask.load(custom_mask)   
    
elif 'waxs' in DET:
    calibration = Calibration(wavelength_A=0.9184) #13.5 keV
    calibration.set_image_size(981, height=1043) # Pilatus1M
    calibration.set_pixel_size(pixel_size_um=172.0)
    #calibration.set_beam_position(304, 732)  
    calibration.set_beam_position(463, 717)  #2024-1
    calibration.set_distance(0.259)
    
    mask_dir = SciAnalysis_PATH + '/SciAnalysis/XSAnalysis/masks/'
    if flag_stitch:
        mask = Mask(mask_dir+'Dectris/Pilatus800k_vertical_gaps-mask.png')
    else:
        mask = Mask(mask_dir+'Dectris/Pilatus800k_gaps-mask.png')   
    mask.load(mask_dir+'NSLSII_11BM_CMS/Pilatus800k_CMS_badpixels-mask.png')
    mask.load(EXPR_DIR+DET+'/analysis/mask_auto.png')
    
    
elif 'maxs' in DET:
    calibration = Calibration(wavelength_A=0.9184) #13.5 keV
    calibration.set_image_size(981, height=1043) # Pilatus1M
    calibration.set_pixel_size(pixel_size_um=172.0)
    calibration.set_beam_position(555, 1043-392)  #2024-C1 Loo
    calibration.set_distance(0.212)
    
    mask_dir = SciAnalysis_PATH + '/SciAnalysis/XSAnalysis/masks/'
    if flag_stitch==0:
        mask = Mask(mask_dir+'Dectris/Pilatus800k2_gaps-mask.png')
    else:
        mask = Mask(mask_dir+'Dectris/Pilatus800k2_generic-mask.png')  
    #if 1:
    #    custom_mask = EXPR_DIR+'maxs/analysis/mask.png'
    #    mask.load(custom_mask)       
    
####################################################################3       
load_args = { 'calibration' : calibration, 
             'mask' : mask,
             }
run_args = { 'verbosity' : 3,
             'AgBH': True, 
             'CeO2': False
           }
process = Protocols.ProcessorXS(load_args=load_args, run_args=run_args)

### Load & analyze the One file
exp.defFiles(fn=pattern, verbose=1)     
det = exp.dict['expinfo']['det']
folder = exp.dict['expinfo']['folder']
infile_fullpath = folder+'/'+det+'/raw/'+exp.dict['rawinfo']['filename'][-1]+'_'+det+'.tiff'

data = process.load(infile_fullpath, calibration=calibration, mask=mask, run_args=run_args)
circular_average_0 = data.circular_average_q_bin(error=False)
# linecut_qr_0 = data.linecut_qz(qr=0, dq=0.02) # WAXS
linecut_0 = data.linecut_qz(qr=0.0, dq=0.005, qmode='qx') #(qz=0, dq=0.002*10)

### Save to PNG for defining mask in GIMP
output_dir = folder+'/'+det+'/analysis/calibration_check/'
print(output_dir)
tools.make_dir(output_dir)
outfile = output_dir + data.name + '.png'
data.plot_image(outfile, zmax=3500)
  
    
### Plot 2D 
# %matplotlib inline
#%matplotlib ipympl

plt.figure(1, figsize=(8,8)); plt.clf()
ax1 = plt.gca()
ax1.imshow(np.log(data.data+3), vmin=4, vmax=9); #plt.colorbar() 
ax1.set_xlabel('pixel'); ax1.set_ylabel('pixel')

q_data = data.remesh_qr_bin(**run_args)
x_axis, y_axis = q_data.xy_axes()
extent = [x_axis[0], x_axis[-1], y_axis[0], y_axis[-1]]
ax2 = ax1.twinx().twiny()
ax2.plot([x_axis[0], x_axis[-1]], [y_axis[0], y_axis[-1]], '.', markersize=1)
ax2.set_xlabel('q (A^-1) -- roughly, need to double check')
ax2.set_ylabel('q (A^-1)')
plt.tight_layout()

### Plot calibrant rings
dq = 0.02
qlist = [0]
if 'AgBH' in run_args and run_args['AgBH']:
    q0 = 0.1076
    num_rings = 15
    qlist.extend(q0*np.arange(1,num_rings+1))       

if 'CeO2' in run_args and run_args['CeO2']:
    q0 = (2*np.pi/5.411)*np.sqrt(3)          # A^-1, (111)
    qlist.extend( ( q0/np.sqrt(3) )*np.array((np.sqrt(3), 2, np.sqrt(8),np.sqrt(11),np.sqrt(12),np.sqrt(16),np.sqrt(19),  np.sqrt(20)))  )

qlist.sort();     qlist = np.asarray(qlist)
print('\nCalibration qlist = {}\n'.format(qlist))    

for q in qlist:
    region = data.calibration.q_map()
    region = np.ma.masked_where(abs(region-q)>dq, region)
    ax1.imshow(region, cmap='gray')

    
## Plot 1D 
if 1:
    flag_log = [1, 0]
    for ii, line in enumerate([circular_average_0, linecut_0]):
        plt.figure(ii+2, figsize=(10,6)); plt.clf()
        q_peaks = Tools.plot_peaks(line, N_peaks_find = 10, fit_param=[0, 1, 0.01], flag_log=flag_log, line_color='k', label_color='g', roundup=4, verbose=1)  #Tools.rand_color(0.5, 0.8)

        y_range = [np.min(line.y), np.max(line.y)]
        qlist[qlist > np.max(line.x)] = None
        Tools.label_peaks(qlist, flag_log=flag_log, y_range = y_range, color='r', roundup=4, verbose=1)
# Out:
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/test3/maxs/raw/
# Loading 1 files
# Sorting files by scanid
# CMS
# Loaded 1 files.
# (defFiles time = 0.0s)
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/test3//maxs/analysis/calibration_check/
# /nsls2/data/cms/legacy/xf11bm/software/SciAnalysis/SciAnalysis/XSAnalysis/Data.py:1016: RuntimeWarning: invalid value encountered in divide
#   remesh_data = np.nan_to_num( remesh_data/num_per_bin )
# Calibration qlist = [0.     0.1076 0.2152 0.3228 0.4304 0.538  0.6456 0.7532 0.8608 0.9684
#  1.076  1.1836 1.2912 1.3988 1.5064 1.614 ]
#
# fit_param = [height, width, prominence]
# 10 peaks found: [0.219  0.3248 0.4304 0.5359 0.6413 0.7469 1.3522 1.6078 1.791  2.3298] for fit_prom 0.23436
# fit_param = [height, width, prominence]
# 10 peaks found: [0.2219 0.3271 0.4321 0.5367 0.6465 0.7503 1.3443 1.6027 1.7819 2.2815] for fit_prom 0.31588

# %%
dx = linecut_qr_0.x[0]-linecut_qr_0.x[1]
print(dx)

# %% [markdown]
# #### __Bad pixels__

# %%
det = exp.dict['expinfo']['det']
folder = exp.dict['expinfo']['folder']
infile_fullpath = folder+'/'+det+'/raw/'+exp.dict['rawinfo']['filename'][-1]+'_'+det+'.tiff'

data = Data2DScattering()
data.load(infile_fullpath)
img = data.data

# %matplotlib inline
plt.figure(1); plt.imshow(np.log(img+3), vmin=0, vmax=7); plt.colorbar()

# %% [markdown]
# __Auto mask__

# %%
delta = 150
center = [757-1, 1679-601] #[463, 654]  
range_y = [int(center[1] - delta), int(center[1] + delta)]
range_x = [int(center[0] - delta), int(center[0] + delta)]
limits = np.asarray([0.1, 70])
mean_img = np.mean(np.concatenate((img[:min(range_y), :].flatten(),
                                   img[max(range_y):, :].flatten(),
                                   img[:, :min(range_x)].flatten(),
                                   img[:, max(range_x):].flatten())), axis=0)
limits = limits * mean_img
print(max(limits))
mask_bkg = np.empty_like(img, dtype=bool)
mask_bkg[:, :] = False
mask_bkg[:min(range_y), :][img[:min(range_y), :] > max(limits)] = True
mask_bkg[max(range_y):, :][img[max(range_y):, :] > max(limits)] = True
mask_bkg[:, :min(range_x)][img[:, :min(range_x)] > max(limits)] = True
mask_bkg[:, max(range_x):][img[:, max(range_x):] > max(limits)] = True
mask_bkg[img < - 0.1] = True

#mask_bkg[520 : 521 + 1, 546] = True
#mask_bkg[520 : 521 + 1, 546] = True
#mask_bkg[520 : 521 + 1, 552 : 554 + 1] = True

fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12, 8))
ax[0].imshow(img*np.logical_not(mask_bkg), vmax=np.percentile(img, 99.0))
ax[1].imshow(img, vmax=np.percentile(img, 99.0))
ax[2].imshow(mask_bkg)
ax[2].scatter(np.where(mask_bkg)[1],
              np.where(mask_bkg)[0], s=0.1, color='r')
for axi, title in zip(ax, ['corrected', 'raw', 'removed pixels']):
    axi.set_title(title, size=10)
# Out:
# 85.023799243795

# %%
## Save to PNG, for use in SciAnalysis
from PIL import Image as im
mask_bkg = ~mask_bkg
mask_auto = im.fromarray(mask_bkg)
mask_auto.save(EXPR_DIR+DET+'/analysis/mask_auto.png')

# %% [markdown]
# #### __Convert q <--> angle__

# %%
print('Experiment performed at {} keV'.format(calibration.get_energy()))

## Convert from q 
q_invA_list = [0.09448, 0.09535]
for q in q_invA_list:
    print('-------\nq = {} (A^-1) = {} (nm^-1)'.format(q, q/0.1))
    print('q = {} (A^-1) <===> 2theta = {:.3f} (deg)'.format(q, data.calibration.q_to_angle(q)))
    print('q = {} (A^-1) <===> d-spacing = {:.3f} (nm)'.format(q, 2*np.pi/(q/0.1)))
print(np.diff(q_invA_list))


## Convert from 2theta 
anlge_deg = 45
print('-------')
print('{} (deg) <===> {:.3f} (A^-1)'.format(anlge_deg, data.calibration.angle_to_q(anlge_deg)))

# %% [markdown]
# ## 1. &#9733; Raw data

# %%
### Specify directory, detector, and files of interest
DET = 'maxs'
EXPR_DIR = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1/'

exp = Experiment.experiment('EW_PbI2', folder=EXPR_DIR, det=DET, beamline='None') ##Experiment name: rbitrary or related to the sample name
#exp.dict['expinfo']['fn_patterns'] = ['*SM_s1*pos1*th0.2*', '*SM_s3*pos1*th0.2*'] #['SM_thermals4_*30.00*'] #['SC*CS*pos1*th0.15*'] #['SC*FP1**RPM3*T30*V18*pos1*th0*']  
exp.dict['expinfo']['fn_patterns'] = ['*EW_*spin*',] #['SM_thermals4_*30.00*'] #['SC*CS*pos1*th0.15*'] #['SC*FP1**RPM3*T30*V18*pos1*th0*']  

#exp = Experiment.experiment('SM_b1', folder=EXPR_DIR, det='saxs', beamline='None') ##Experiment name: rbitrary or related to the sample name
#exp.dict['expinfo']['fn_patterns'] = ['*SM_b1*'] #['SM_thermals4_*30.00*'] #['SC*CS*pos1*th0.15*'] #['SC*FP1**RPM3*T30*V18*pos1*th0*']  

    
### Load files
try:
    for pattern in exp.dict['expinfo']['fn_patterns']:
        #exp.defFiles_query(fn='PBG', folder=EXPR_DIR, scanid = [900000, 1200000], verbose=1) 
        exp.defFiles(fn=pattern, verbose=1) 
        #exp.defFiles(fn=pattern, scanid = [750000, 900000], verbose=1)  
    
    infiles = exp.dict['rawinfo']['filename']
    Nfiles = len(infiles)
    
except:
    print('\n!!! Databroker not working, loading files directly.')
    #exp.dict['expinfo']['beamline'] = None
    for pattern in exp.dict['expinfo']['fn_patterns']:
        exp.defFiles(fn=pattern, verbose=1)      
    

### Show some info   
exp.show()
exp.showFileInfo(idx=0)
exp.showFileInfo(idx=1)
# Out:
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1/maxs/raw/
# Loading 240 files
# Sorting files by scanid
# CMS
# Loaded 240 files.
# (defFiles time = 0.0s)
#
# === Overview of experiment dictionary ===
# exp.dict['expinfo']
#   -  keys = ['expname', 'det', 'beamline', 'folder', 'ext', 'fn_patterns']
#   -  key = expname, <class 'str'>, val = EW_PbI2
#   -  key = det, <class 'str'>, val = maxs
#   -  key = beamline, <class 'str'>, val = None
#   -  key = folder, <class 'str'>, val = /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1/
#   -  key = ext, <class 'str'>, val = tiff
#   -  key = fn_patterns, <class 'list'>
# exp.dict['rawinfo']
#   -  keys = ['filename', 'time', 'clock', 'scan_id', 'uid', 'filenumber', 'series_measure', 'num_frames']
#   -  key = filename, <class 'list'>, len(shape) = 240
#   -  key = time, <class 'list'>, val = []
#   -  key = clock, <class 'list'>, val = []
#   -  key = scan_id, <class 'list'>, len(shape) = 240
#   -  key = uid, <class 'list'>, val = []
#   -  key = filenumber, <class 'int'>, val = 240
#   -  key = series_measure, <class 'bool'>, val = False
#   -  key = num_frames, <class 'int'>, val = 1
# exp.dict['analysis']
# exp.dict['metadata']
# exp.dict['advanced']
#
# === Raw Information for File 0 ===
# exp.dict['rawinfo']['filename'][0] = EW_FAI0_PbI20_hum50_air_run1_spin_750.3s_RH50.817_x-0.001_th0.300_0.49s_1343111_000000
# exp.dict['rawinfo']['scan_id'][0] = 000000
#
# === Raw Information for File 1 ===
# exp.dict['rawinfo']['filename'][1] = EW_FAI0_PbI20_hum50_air_run1_spin_750.3s_RH50.817_x-0.001_th0.300_0.49s_1343111_000001
# exp.dict['rawinfo']['scan_id'][1] = 000001

# %% [markdown]
# ### Sort (todo: sort all rawinfo)

# %%
print(infiles[0].split('x')[1].split('_')[0])
print(infiles[0].split('_'+'maxs')[0].split('_')[-2])
# Out:
# -0.001
# 1341232

# %%
#print(infiles[0].split('_'+det)[0].split('_')[-2])

infiles = exp.dict['rawinfo']['filename']
infiles = sorted(infiles, key=lambda x: x.split('_'+'maxs')[0].split('_')[-2]) 
#infiles = sorted(infiles, key=lambda x: float(x.split('x')[1].split('_')[0])) 

exp.dict['rawinfo']['filename'] = infiles


### Show some info   
exp.showFileInfo(idx=0)
exp.showFileInfo(idx=1)
exp.showFileInfo(idx=2)
exp.showFileInfo(idx=100)
# Out:
# === Raw Information for File 0 ===
# exp.dict['rawinfo']['filename'][0] = EW_FAI0_PbI20_hum25_air_run1_spin_954.2s_RH23.893_x-0.001_th0.300_0.49s_1343073_000000
# exp.dict['rawinfo']['scan_id'][0] = 000000
#
# === Raw Information for File 1 ===
# exp.dict['rawinfo']['filename'][1] = EW_FAI0_PbI20_hum25_air_run1_spin_954.2s_RH23.893_x-0.001_th0.300_0.49s_1343073_000001
# exp.dict['rawinfo']['scan_id'][1] = 000001
#
# === Raw Information for File 2 ===
# exp.dict['rawinfo']['filename'][2] = EW_FAI0_PbI20_hum25_air_run1_spin_954.2s_RH23.893_x-0.001_th0.300_0.49s_1343073_000002
# exp.dict['rawinfo']['scan_id'][2] = 000002
#
# === Raw Information for File 100 ===
# exp.dict['rawinfo']['filename'][100] = EW_FAI0_PbI20_hum25_air_run1_spin_954.2s_RH23.893_x-0.001_th0.300_0.49s_1343073_000100
# exp.dict['rawinfo']['scan_id'][100] = 000100

# %% [markdown]
# ## 2. (Optional) Metadata

# %% [markdown]
# #### __Databroker with catalog__

# %%
## Check databroker or load some scan info

import databroker, datetime
cat = databroker.catalog['cms']
#scan_id = exp.dict['rawinfo']['scan_id'][0]  #959455
scan_id =  1135011 #1135011 #1134889 #1134846 #1135309
h = cat[scan_id]

print(h.metadata['start']['experiment_alias_directory'])
print('empty scan: ', scan_id)
for scan_id in range(scan_id-5, scan_id+6):
    h = cat[scan_id]

    dt = datetime.datetime.fromtimestamp(h.metadata['start']['time'])
    det = h.metadata['start']['detectors']
    ct = h.metadata['start']['sample_exposure_time']

    #h.metadata['start']
    print('scanid {}, time {}, det {}, exposure {}s'.format(scan_id, dt, det, ct))

# %% [markdown]
# __Browse metadata__

# %%
## See metadata for one file
import databroker, datetime
cat = databroker.catalog['cms']
#scan_id = exp.dict['rawinfo']['scan_id'][0]  #959455
scan_id =  1135011 #1135011 #1134889 #1134846 #1135309
h = cat[scan_id]
h.metadata['start']

# %%
### Check metadata at the beamline, identify md of interest, e.g. sample_temperature_D, sample_x
file_idx = 0
scan_id = exp.dict['rawinfo']['scan_id'][file_idx]
#exp.showMetadata(scanid=scan_id, md_interest=None)
exp.showMetadata(scanid=scan_id, md_interest = ['sample_clock', 'sample_x'])
#exp.showMetadata(scanid=scan_id, md_interest = ['sample_clock', 'sample_x', 'sample_y'])

# %% [markdown]
# #### __Databroker with db__

# %% [markdown]
# __Check one file__

# %%
import databroker, datetime

scan_id =  1341187 #1318713 
db = databroker.DataBroker.named('cms')
h = db[scan_id]

## Get metadata stored in h.start
print(h.start['experiment_alias_directory'])
print(h.start)

## Get metadata not stored in h.start
if 0:
    masky_pos = h.table()['strans2'].to_numpy()
# Out:
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_air_hum0_run5_4V
#
# Run Start
# =========
# beam_intensity_e: 20000
# calibration_ener: 13.5
# calibration_wave: 0.9184
# experiment_SAF_n: 312935
# experiment_alias: /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_air_hum0_run5_4V
# experiment_cycle: 2024_1
# experiment_group: L Loo (Princeton)
# experiment_proje: Organic semiconductor and perovskite
# experiment_propo: 310015
# experiment_type : GIWAXS
# experiment_user : various
# plan_name       : runSpinner_duo
# plan_type       : generator
# platform_beam   : 45
# sample_clock_zer: 1691164924.0269682
# scan_id         : 1341187
# time            : 1706050828.9795883
# uid             : 4c3792fb-99e7-4876-8dab-ce498c54eec6

# %% [markdown]
# __Multiple files__

# %%
import databroker, datetime
import json
#--------------------------------------
def numpy_encoder(obj):
    if isinstance(obj, (np.int_, np.intc, np.intp, np.int8,
                        np.int16, np.int32, np.int64, np.uint8,
                        np.uint16, np.uint32, np.uint64)):
        return int(obj)
    elif isinstance(obj, (np.float_, np.float16, np.float32, np.float64)):
        return float(obj)
    elif isinstance(obj, (np.ndarray,)):  # This handles arrays and converts them to lists
        return obj.tolist()
    raise TypeError(f"Object of type '{type(obj).__name__}' is not JSON serializable")
#--------------------------------------

db = databroker.DataBroker.named('cms')

scan_id_list = exp.dict['rawinfo']['scan_id']
## Remove duplicates
scan_id_list = list(dict.fromkeys(scan_id_list))
print(scan_id_list)

for scan_id in scan_id_list:
    scan_id = np.int(scan_id)
    h = db[scan_id]

    ## Get metadata stored in h.start
    print(h.start['experiment_alias_directory'])
    #print(h.start)

    ## Get metadata not stored in h.start
    if 1:
        masky_pos = h.table()['strans2'].to_numpy()


    # Save    
    file_path = h.start['experiment_alias_directory'] + 'data/scan{}_masky.json'.format(scan_id)

    with open(file_path, 'w') as file:
        #json.dump(h.start, file, indent=4, default=numpy_encoder)
        json.dump(h.table()['strans2'].to_numpy(), file, indent=4, default=numpy_encoder)

# %% [markdown]
# ##### (i) Save/load via npy

# %%
## Save as npy
   
file_path = h.start['experiment_alias_directory'] + 'data/test.npy'

np.save(file_path, masky_pos)

## Load data
x = np.load(file_path)
print(x)

# %% [markdown]
# ##### (ii) Save/load via json

# %%
import json
#--------------------------------------
def numpy_encoder(obj):
    if isinstance(obj, (np.int_, np.intc, np.intp, np.int8,
                        np.int16, np.int32, np.int64, np.uint8,
                        np.uint16, np.uint32, np.uint64)):
        return int(obj)
    elif isinstance(obj, (np.float_, np.float16, np.float32, np.float64)):
        return float(obj)
    elif isinstance(obj, (np.ndarray,)):  # This handles arrays and converts them to lists
        return obj.tolist()
    raise TypeError(f"Object of type '{type(obj).__name__}' is not JSON serializable")
#--------------------------------------

# %%
## Save as json
   
file_path = h.start['experiment_alias_directory'] + 'data/test.json'

with open(file_path, 'w') as file:
    #json.dump(h.start, file, indent=4, default=numpy_encoder)
    json.dump(h.table()['strans2'].to_numpy(), file, indent=4, default=numpy_encoder)

    

## Load data
f = open(file_path)
x = json.load(f)
print(x)
f.close()

# %% [markdown]
# #### __Load metadata__

# %%
## Options: 
## (1) load metadata from databroker at beamline. 
## (2) load md from h5. 
## (3) Extract info from filename
md_load_option = 3

## Clear all metadata
exp.dict['metadata'] = {}


## Load metadata
if md_load_option==1: # Load md from databroker, this only works at beamline
    exp.dict['mdata_list'] = ['sample_clock'] # Specify metedata to load
    exp.loadMetadata()
    print(exp.dict['metadata'].keys())
    
elif md_load_option==2: # Load md from h5 (previously saved from databroker)
    h5_path = EXPR_DIR+"/data/"
    h5_file = 'B6_N3_metadata.h5'
    exp.dict['metadata'] = h5todict(h5_path+h5_file)


elif md_load_option==3: ## If databroker md is not available nor saved
    infiles = exp.dict['rawinfo']['filename']
    print('Number of files: {}'.format(len(infiles)))

    Ts = []
    sample_x = []
    sample_y = []
    scan_id = []
    frames = []
    for ii, infile in enumerate(infiles):
        temp = infile.split('_')
        if ii==0: print(temp)
        
        Ts.append(float(infile.split('Linkam')[1].split('C')[0]))
        #sample_x.append(float(temp[-4][1:]))
        #sample_y.append(float(temp[-3][1:]))
        
        #Ts.append(float(infile.split('RH')[1].split('_x')[0]))
        #scan_id.append(int(temp[-1]))
        #frames.append(int(temp[-1]))

    exp.dict['metadata']['sample_temperature_D'] = Ts
    #exp.dict['metadata']['sample_x'] = np.array(sample_x)
    #exp.dict['metadata']['sample_y'] = np.array(sample_y)
    #exp.dict['metadata']['frames'] = frames
    
    print(exp.dict['metadata'].keys())

else:
    print('No metadata loaded to the exp. dictionary!')
# Out:
# Number of files: 326
# ['SA', 'PBG', 'air', 'insitu', 'capL', 'Seprun1', '1', '0.0s', 'Linkam32.6C', 'x0.000', 'y0.000', '5.00s', '1178661']
# dict_keys(['sample_temperature_D'])

# %%
exp.show()

# %%
### Save metadata (for offline analysis later on)
if 0:
    h5_path = EXPR_DIR+"/data/"
    h5_file = exp.name+'_metadata.h5'
    dicttoh5(exp.dict['metadata'], h5_path+h5_file)
    print(h5_path+h5_file)

# %% [markdown]
# ## 3. &#9733; Analysis
#
# We suspect that loading analysis results is slow, faster if processing raw data. However, going through the protocals is also slow; storing it to the exp.dict also takes a bit time.
#
# E.g. 3600 files, 1 protocol, saving to exp.dict: 5min

# %%
### Specify beamline config (e.g. beam energy, center, det-sample distance)
        
#---------------------------------------------------        
load_args = { 'calibration' : calibration, 
             'mask' : mask,
             #'rot180' : False,
             #'flip' : True, # PSCCD
             }
run_args = { 'verbosity' : 3,
            #'save_results' : ['xml', 'plots', 'txt', 'hdf5'],
            }
process = Protocols.ProcessorXS(load_args=load_args, run_args=run_args)
if 0:
    infiles = [exp.dict['rawinfo']['filename'][0]]
    print(infiles)

### Run analysis 
protocols = ['circular_average'] #['linecut_angle'] #['circular_average'] #, 'sector_average', 'linecut_qz']

exp.dict['analysis']['cali'] = [calibration.wavelength_A, calibration.x0, calibration.y0, calibration.distance_m]
#exp.dict['analysis'] = {} 
#for protocol in protocols:
#    exp.dict['analysis'][protocol] = {}

t0 = time.time()  
    
line_y_stack = []
for protocol in protocols:
    if 'circular_average' in protocol:
        for ii, infile in enumerate(infiles):
            if np.mod(ii+1, 50)==0: print('[{:.0f}%]'.format(ii/Nfiles*100))

            det = exp.dict['expinfo']['det']
            folder = exp.dict['expinfo']['folder']

            infile_fullpath = folder+'/'+det+'/raw/'+exp.dict['rawinfo']['filename'][ii]+'_'+det+'.tiff'
            data = process.load(infile_fullpath, calibration=calibration, mask=mask, run_args=run_args)

            ### Run the protocol
            line_output = data.circular_average_q_bin(error=False)
            line_y_stack.append(line_output.y)

            if 0:
                exp.dict['analysis'][protocol][str(ii)] = {}
                exp.dict['analysis'][protocol][str(ii)]['q'] = line_output.x
                exp.dict['analysis'][protocol][str(ii)]['I(q)'] = line_output.y
        
        ### Save analysis to exp.dict
        if 1:
            exp.dict['analysis'][protocol] = {}
            exp.dict['analysis'][protocol]['q'] = line_output.x
            exp.dict['analysis'][protocol]['I_stack'] = line_y_stack   
            #x = Protocols.thumbnails(name=None) 
            #x.run(data, output_dir)
            
    if 'linecut_qr' in protocol:
        for ii, infile in enumerate(infiles):
            if np.mod(ii+1, 50)==0: print('[{:.0f}%]'.format(ii/Nfiles*100))

            det = exp.dict['expinfo']['det']
            folder = exp.dict['expinfo']['folder']

            infile_fullpath = folder+'/'+det+'/raw/'+exp.dict['rawinfo']['filename'][ii]+'_'+det+'.tiff'
            data = process.load(infile_fullpath, calibration=calibration, mask=mask, run_args=run_args)

            ### Run the protocol
            line_output = data.linecut_qr(qz = 0.05, dq = 0.035)
            line_y_stack.append(line_output.y)

        ### Save analysis to exp.dict
        if 1:
            exp.dict['analysis'][protocol] = {}
            exp.dict['analysis'][protocol]['q'] = line_output.x
            exp.dict['analysis'][protocol]['I_stack'] = line_y_stack           
        
    #elif 'sector_average' in protocol: 
    #    line_output = data.sector_average_q_bin(angle=60, dangle=5)

    #elif 'linecut_qz' in protocol:
    #    line_output = data.linecut_qz(qr=0, dq=0.05)

    #elif 'linecut_angle' in protocol:
    #line_output = data.linecut_angle(q0=2.24, dq=0.01)
            
        
print('Done! (Analysis took {:.0f}s)\n'.format(time.time()-t0))

now = datetime.datetime.now()
dt_string = now.strftime("%Y/%m/%d %H:%M:%S")
print("{}\n".format(dt_string))

print(exp.dict['analysis'].keys())
# Out:
# [20%]
# [41%]
# [62%]
# [83%]
# Done! (Analysis took 7s)
#
# 2024/01/24 19:32:57
#
# dict_keys(['cali', 'circular_average'])

# %% [markdown]
# #### __Show Region__

# %%
infile = infiles[0]
print(infile)

infile_fullpath = folder+'/'+det+'/raw/'+exp.dict['rawinfo']['filename'][ii]+'_'+det+'.tiff'
data = process.load(infile_fullpath, calibration=calibration, mask=mask, run_args=run_args)

## Plot scattering data
q_data = data.remesh_qr_bin(**run_args)
x_axis, y_axis = q_data.xy_axes()
extent = [x_axis[0], x_axis[-1], y_axis[0], y_axis[-1]]


# %matplotlib inline
plt.figure(1, figsize=(8,8)); plt.clf()
#plt.imshow(np.log(data.data+3), vmin=2, vmax=7); plt.colorbar() 
plt.imshow(np.log(q_data.data+3), vmin=2, vmax=7, cmap='jet', interpolation='nearest', extent=extent, origin='lower'); plt.colorbar()


### Linecut
if 0:
    qz = 0.03; dq = 0.03
    region = data.calibration.q_map()
    region = np.ma.masked_where(abs(data.calibration.qz_map()-qz)>dq, data.calibration.qr_map())
    plt.imshow(region, cmap='plasma', extent=extent, alpha=0.5)

if 0:
    qr = 0.03
    region = np.ma.masked_where(abs(data.calibration.qr_map()-qr)>dq, data.calibration.qz_map())
    plt.imshow(region, cmap='plasma', extent=extent)
    
### Angle
if 0:
    q0 = 0.05;
    dq = 0.001;
    region = np.ma.masked_where(abs(data.calibration.q_map()-q0)>dq, data.calibration.angle_map())
    plt.imshow(region, cmap='plasma', extent=extent)

### Sector
if 0:
    angle = 0
    dangle = 5
    region =  np.ma.masked_where(abs(data.calibration.angle_map()-angle)>dangle/2, data.calibration.q_map())
    plt.imshow(region, cmap='plasma', extent=extent)
# Out:
# EW_PbI2_air_hum50_run2_spin_965.6s_RH48.661_x-0.002_th0.300_0.49s_1341360_000000

# %%
plt.plot(line_output.x, line_output.y)

# %%
exp.show()

# %% [markdown]
# __Instead of doing analysis, can load previously analyzed data__

# %%
if 0:
    exp.loadSciAnalysisData(keys=['circular_average'], analysis_folder=str(exp.dict['folder'])+'waxs/analysis/PBG_run1/', verbose=1)
    exp.dict['analysis'].keys()

# %% [markdown]
# ## 4. Save
#
# Save experiment dictionary (exp.dict) to h5.

# %%
h5_path = EXPR_DIR+"/data/"
h5_file = str(exp.dict['expinfo']['expname']) + '_MAXS.h5'
output_file = h5_path+h5_file


## Check if file exist, will not overwrite
if False:
    file_exist = os.path.isfile(output_file)
    count = 1
    while file_exist:
        print('{} exists, using a new filename'.format(output_file))
        h5_file = str(exp.dict['expname']) + '_MAXS' + str(count) + '.h5'
        output_file = h5_path+h5_file
        file_exist = os.path.isfile(output_file)
        count = count + 1

        
## Save
dicttoh5(exp.dict, output_file)
print('Experiment saved as {}'.format(output_file))
# Out:
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2023_3/beamline/ETsai_SA//data/PBG_Sep_SAXS.h5

# %% [markdown]
# ### __(&#9733;) Load H5__
#
# Load experiment dictionary and recover the object 'exp', allowing for subsequent data visualization/analysis in Section 5.

# %%
#%matplotlib nbagg
# Imports
########################################
import sys, os, time, glob, imageio, datetime, pprint, copy
import sqlite3
import pandas as pd
from silx.io.dictdump import dicttoh5, h5todict
SciAnalysis_PATH='/nsls2/data/cms/legacy/xf11bm/software/SciAnalysis/' ### Specify this
SciAnalysis_PATH in sys.path or sys.path.append(SciAnalysis_PATH)
from SciAnalysis import tools
from SciAnalysis.XSAnalysis.Data import *
from SciAnalysis.XSAnalysis import Protocols
from SciAnalysis.ExpAnalysis import Experiment
from SciAnalysis.ExpAnalysis import Tools


### Load experiment dict (previuosly analyzed data)
if True:

    #exp_dict_h5 = '/nsls2/data/cms/legacy/xf11bm/data/2023_2/SMorozova//data/SM_thermals13_run2_cms_exp.h5'
    exp_dict_h5 = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/Summary/EW_PbI2_N2_hum50_run2_cms_MAXS.h5'
    exp_dict_load = h5todict(exp_dict_h5)
    #print(exp_dict_load.keys())
    
    exp = Experiment.experiment(exp_dict_load['expinfo']['expname'], folder=exp_dict_load['expinfo']['folder'], det=exp_dict_load['expinfo']['det'], beamline=exp_dict_load['expinfo']['beamline']) 
    exp.dict = copy.deepcopy(exp_dict_load)
    
    print(exp.dict.keys())
    print('\nExperiment loaded!')
# Out:
# dict_keys(['advanced', 'analysis', 'expinfo', 'metadata', 'rawinfo'])
#
# Experiment loaded!

# %% [markdown]
# ### __Overview of exp__

# %%
exp.show(verbose=1)

# %% [markdown]
# ## 5. Plot

# %% [markdown]
# ### __(5.1) Data Trend__

# %% [markdown]
# #### &#9642; __Plot curves__

# %% [markdown]
# ##### - __Load one curve & find peaks__

# %%
### Show one curve and find peaks
file_idx = 0
protocol = 'circular_average'
protocol = list(exp.dict['analysis'].keys())[-1]
print(protocol)
print(exp.dict['rawinfo']['filename'][file_idx])

## Pick a curve
line_plot = DataLine(x = exp.dict['analysis'][protocol]['q'], y = exp.dict['analysis'][protocol]['I_stack'][file_idx])  
flag_log = [1, 0]

# %matplotlib inline
#%matplotlib ipympl
plt.figure(1, figsize=(12,5)); plt.clf()
q_peaks = Tools.plot_peaks(line_plot, N_peaks_find = 10, fit_param=[0, 1, 0.001], flag_log=flag_log, line_color='k', label_color='r', verbose=1)  #Tools.rand_color(0.5, 0.8)

q_label = [] #[0.1076]
for q in q_label:
    if flag_log[0]:
        y_range = [0, max(np.log(line_plot.y))]
    else:
        y_range = [min(line_plot.y), max(np.log(line_plot.y))]
    plt.plot([q, q], y_range, 'g',  alpha=0.7)
    plt.text(q, y_range[1]/2, str(q), color='g')
# Out:
# circular_average
# EW_PbI2_air_hum50_run2_spin_965.6s_RH48.661_x-0.002_th0.300_0.49s_1341360_000000
# fit_param = [height, width, prominence]
# 10 peaks found: [0.219  0.3526 1.1413 2.3019 3.2906 3.8681 3.9514 4.0181 4.0291 4.0568] for fit_prom 0.02538

# %% [markdown]
# ##### - __&#9733; Plot all curves as 2D image__

# %%
#I_stack.shape

# %%
q_label = [] #[1.278, 1.88, 2.219, 2.564, 2.905]; # Label the lines
flag_log = [1, 0]

#protocol = 'circular_average'
protocol = list(exp.dict['analysis'].keys())[-1]

x_axis = exp.dict['analysis'][protocol]['q'] 
I_stack = exp.dict['analysis'][protocol]['I_stack']
if flag_log[0]:
    I_stack = np.log(I_stack)

idx0 = 40 
    
# %matplotlib inline
plt.figure(2, figsize=(12,8)); plt.clf()
ax = plt.gca()
plt.imshow(I_stack[:, idx0:], origin='lower', cmap='jet', extent = [np.min(x_axis[idx0:]), np.max(x_axis), 0, I_stack.shape[0]],  aspect='auto') #aspect='auto' 0.005
cbar = plt.colorbar(fraction=0.02, pad=0.02, aspect=40) 
filename = exp.dict['rawinfo']['filename'][0]
plt.title(filename)
plt.xlabel('q (A^-1)')
plt.ylabel('file index')

if 1:
    #Ts = exp.dict['metadata']['sample_temperature_D'] 
    idx_array = np.arange(0, I_stack.shape[0], 60).astype(int)
    ylabel_array = []
    for idx in idx_array:
        ylabel_array.append(np.round(idx/2/60,1))
    ax.set_yticks(idx_array)
    ax.set_yticklabels(ylabel_array)
    plt.ylabel('min')

     
print('q_label = {}'.format(q_label))
for q in q_label:
    plt.plot([q, q], [0, I_stack.shape[0]], 'k',  alpha=0.2)
# Out:
# /tmp/ipykernel_1969090/2968048818.py:10: RuntimeWarning: invalid value encountered in log
#   I_stack = np.log(I_stack)
# q_label = []

# %% [markdown]
# ##### - __&#9733; Plot curves__

# %%
# %matplotlib inline
plt.figure(1, figsize=(8, 8)); plt.clf()
Nfiles = len(exp.dict['rawinfo']['filename'])
infile = exp.dict['rawinfo']['filename'][0]

qrange_plot = [0.4, 3.6] #[0.08, 0.12] ###
q_label = []; q_peaks #[1.278, 1.88, 2.219, 2.564, 2.905]; # Label the lines

cmap = mpl.colormaps['jet'] #viridis, jet, hsv, brg
colors = cmap(np.linspace(0.0, 1.0, Nfiles))
flag_log = [1, 0]

#sample_temperature_D = exp.dict['metadata']['sample_temperature_D']
scan_ids = exp.dict['rawinfo']['scan_id']
filenames = exp.dict['rawinfo']['filename']

### Plot
protocol = 'circular_average'
x_axis = exp.dict['analysis'][protocol]['q'] 
idx_min = int(np.argmin(np.abs(x_axis-qrange_plot[0])))
idx_max = int(np.argmin(np.abs(x_axis-qrange_plot[1])))

I_stack = exp.dict['analysis'][protocol]['I_stack']
spacing_plot = 0.002 #arbitrary

if flag_log[0]:
    I_stack = np.log(I_stack)
    
st_legend = []
if 0:
    for ii, filename in zip(np.arange(Nfiles), filenames):
        #print('{}:, {}'.format(ii, filename))
        color = colors[ii]
        linestyle = None
        if 'T34' in filename or 'T33' in filename: #or 'x0.0' in filename:
            linestyle = ':'       

        plt.plot((x_axis[idx_min:idx_max]),I_stack[ii][idx_min:idx_max], linestyle=linestyle, color=color, label=str(ii)+': '+filename[0:filename.find('pos1')]) #label=filename[0:filename.find('pos1')   
        #st_legend.append(filename)
        
if 1:
    for ii, filename in zip(np.arange(Nfiles), filenames):
        #print('{}:, {}'.format(ii, filename))
        color = colors[ii]
        linestyle = None

        plt.plot((x_axis[idx_min:idx_max]),I_stack[ii][idx_min:idx_max]+ii*spacing_plot+spacing_plot*5, linestyle=linestyle, color=color, label=str(ii)+': '+filename[0:filename.find('pos1')]) #label=filename[0:filename.find('pos1')
        #plt.plot((x_axis[idx_min:idx_max]),I_stack[ii][idx_min:idx_max]+ii*spacing_plot+spacing_plot*5+offset, linestyle=linestyle, color=color, label=str(ii)+': '+filename[0:filename.find('pos1')]) #label=filename[0:filename.find('pos1')
        #plt.plot(np.log10(x_axis),I_stack[ii]+ii*spacing_plot, linestyle=linestyle, color=color, label=str(ii)+': '+filename[0:filename.find('pos1')]) #label=filename[0:filename.find('pos1')

        #if np.mod(ii,5)==0:
        #    plt.text(x_axis[idx_min], I_stack[ii][idx_min]+ii*spacing_plot, str(ii))
        #plt.grid('minor')
        #st_legend.append(filename)

for q in q_label:
    plt.plot([q, q], [min(I_stack[0])*0.8, max(I_stack[0])*1.2+Nfiles*spacing_plot], 'k',  alpha=0.2)   
    
plt.legend(st_legend, fontsize=8, ncols=1, bbox_to_anchor=(1.01, 1.01)) 
plt.title('{}, \nN={}, spacing_plot={}'.format(infile.split('raw')[-1], Nfiles, spacing_plot))
plt.grid()

plt.savefig(str(exp.dict['expinfo']['folder']) + 'data/' + str(exp.dict['expinfo']['expname'])+'.png')
# Out:
# /tmp/ipykernel_1969090/3016755718.py:27: RuntimeWarning: invalid value encountered in log
#   I_stack = np.log(I_stack)

# %%
# %matplotlib inline
plt.figure(1, figsize=(12, 12)); plt.clf()
Nfiles = len(exp.dict['rawinfo']['filename'])
infile = exp.dict['rawinfo']['filename'][0]

qrange_plot = [0.0, 0.2] #[0.08, 0.12] ###
q_label = []; q_peaks #[1.278, 1.88, 2.219, 2.564, 2.905]; # Label the lines

cmap = mpl.colormaps['viridis'] #viridis, jet, hsv, brg
colors = cmap(np.linspace(0.0, 1.0, Nfiles))
flag_log = [1, 0]

#sample_temperature_D = exp.dict['metadata']['sample_temperature_D']
scan_ids = exp.dict['rawinfo']['scan_id']
filenames = exp.dict['rawinfo']['filename']

### Plot
protocol = 'circular_average'
x_axis = exp.dict['analysis'][protocol]['q'] 
idx_min = int(np.argmin(np.abs(x_axis-qrange_plot[0])))
idx_max = int(np.argmin(np.abs(x_axis-qrange_plot[1])))

I_stack = exp.dict['analysis'][protocol]['I_stack']
spacing_plot = 1 #arbitrary

if flag_log[0]:
    I_stack = np.log(I_stack)
    
st_legend = []
for ii, filename in zip(np.arange(Nfiles), filenames):
    #print('{}:, {}'.format(ii, filename))
    #color = colors[ii]
    linestyle = None
    linewidth = 1
    if 'air' in filename:
        offset = spacing_plot*10
        if 's1' in filename or 's2' in filename:
            linestyle = ':'
            color = 'gray'
        elif 's5' in filename or 's6' in filename: 
            color = 'm'
        elif 's3' in filename:
            color = 'g'
        elif 's4' in filename:
            color = 'c'
    else:
        offset = 0        
        if 's1' in filename or 's2' in filename:
            linestyle = ':'
            color = 'k'
        elif 's5' in filename or 's6' in filename: 
            color = 'r'
        elif 's3' in filename:
            color = 'g'
        else:
            color = 'b'

    
    plt.plot((x_axis[idx_min:idx_max]),I_stack[ii][idx_min:idx_max]+offset, linestyle=linestyle, linewidth=linewidth, color=color, label=str(ii)+': '+filename[0:filename.find('pos1')]) #label=filename[0:filename.find('pos1')
    #plt.plot(np.log10(x_axis),I_stack[ii]+ii*spacing_plot, linestyle=linestyle, color=color, label=str(ii)+': '+filename[0:filename.find('pos1')]) #label=filename[0:filename.find('pos1')
    
    #if np.mod(ii,5)==0:
    #    plt.text(x_axis[idx_min], I_stack[ii][idx_min]+ii*spacing_plot, str(ii))
    #plt.grid('minor')
    st_legend.append(filename)

for q in q_label:
    plt.plot([q, q], [min(I_stack[0])*0.8, max(I_stack[0])*1.2+Nfiles*spacing_plot], 'k',  alpha=0.2)   
    
plt.legend(st_legend, fontsize=6, ncols=1, bbox_to_anchor=(1.01, 1.01)) 
plt.title('{}, N={}, spacing_plot={}'.format(infile.split('raw')[-1], Nfiles, spacing_plot))
plt.grid()

plt.savefig(str(exp.dict['expinfo']['folder']) + 'data/' + str(exp.dict['expinfo']['expname'])+'.png')

# %%
str(exp.dict['expinfo']['folder']) + 'data/'

# %% [markdown]
# __Plot a 2D image__

# %%
file_idx = 13;
infile_fullpath = folder+'/'+det+'/raw/'+exp.dict['rawinfo']['filename'][file_idx]+'_'+det+'.tiff'
print(infile_fullpath)
data = process.load(infile_fullpath, calibration=calibration, mask=mask, run_args=run_args)

## Plot scattering data
q_data = data.remesh_qr_bin(**run_args)
x_axis, y_axis = q_data.xy_axes()
extent = [x_axis[0], x_axis[-1], y_axis[0], y_axis[-1]]

# %matplotlib inline
plt.figure(1, figsize=(8,8)); plt.clf()
#plt.imshow(np.log(data.data+3), vmin=2, vmax=7); plt.colorbar() 
plt.imshow(np.log(q_data.data+3), vmin=1, vmax=5, cmap='jet', interpolation='nearest', extent=extent, origin='lower'); plt.colorbar()
plt.title(exp.dict['rawinfo']['filename'][file_idx])

### Linecut
if 1:
    qz = 0.05; dq = 0.035
    region = data.calibration.q_map()
    region = np.ma.masked_where(abs(data.calibration.qz_map()-qz)>dq, data.calibration.qr_map())
    plt.imshow(region, cmap='plasma', extent=extent, alpha=0.2)

    qr = 0.03; dq = 0.001
    region = np.ma.masked_where(abs(data.calibration.qr_map()-qr)>dq, data.calibration.qz_map())
    plt.imshow(region, cmap='plasma', extent=extent)

    qr = 0.037; dq = 0.001
    region = np.ma.masked_where(abs(data.calibration.qr_map()-qr)>dq, data.calibration.qz_map())
    plt.imshow(region, cmap='plasma', extent=extent)
    
## Plot reduced data
line_output = data.linecut_qr(qz = 0.05, dq = 0.035)
plt.figure(2, figsize=(8,5)); plt.clf()
plt.plot(line_output.x, np.log10(line_output.y))

# %% [markdown]
# #### &#9642; __Extract 0D feature & Plot 1D trend__

# %% [markdown]
# ##### - __Load one curve for peak fitting__

# %%
### Show one curve & do fitting
protocol = 'circular_average'

file_idx = 3
line_plot = DataLine(x = exp.dict['analysis'][protocol]['q'], y = exp.dict['analysis'][protocol]['I_stack'][file_idx])  

q0 = [0.03, 0.037] #[2.64964595, 3.07210364] #[1.82, 1.86]
fit_range = [0.02, 0.045] #[2.5, 3.2] #[1.7, 1.95]

flag_log = [1, 0]
if flag_log[0] == 1:
    line_plot.y = np.log(line_plot.y)

## Fitting
run_args = { 'verbosity' : 3,
             #'fittype': 'voigt',
            }
results = {}
protocol = Protocols.fit_peaks()
lines = protocol._fit(line_plot, results, **run_args, q0=q0, num_curves=len(q0), fit_range=fit_range)

plt.figure(10, figsize=(10,5)); plt.clf()
for nn, line in enumerate(lines.lines):
        
    if nn==0: 
        plt.plot(line.x, line.y, 'k', linewidth=1, label=line.name)
        plt.title(line.name)
    elif nn==1:
        plt.plot(line.x, line.y, 'm', linewidth=2, label=line.name)
    else:
        plt.plot(line.x, line.y, 'r', linewidth=1, label=line.name)
        
    plt.grid()
    
pprint.pprint(lines.results)

# %% [markdown]
# ##### - __Apply fitting for all__

# %%
protocol = 'linecut_qr'
q0 = [0.03, 0.037] #[2.64964595, 3.07210364] #[1.82, 1.86]
fit_range = [0.02, 0.045] #[2.5, 3.2] #[1.7, 1.95]


## Fitting
run_args = { 'verbosity' : 3,
             #'fittype': 'voigt',
            }
p = Protocols.fit_peaks()
    

## Fitting all curves
peak_x1 = []
peak_x2 = []
peak_pre1 = []
peak_pre2 = []
t0 = time.time()
for ii in np.arange(Nfiles):
    line_plot = DataLine(x = exp.dict['analysis'][protocol]['q'], y = exp.dict['analysis'][protocol]['I_stack'][ii])  
    
    lines = p._fit(line_plot, results={}, **run_args, q0=q0, num_curves=len(q0), fit_range=fit_range)

    peak_x1.append(lines.results['fit_peaks_x_center1']['value'])
    peak_x2.append(lines.results['fit_peaks_x_center2']['value'])
    peak_pre1.append(lines.results['fit_peaks_prefactor1']['value'])
    peak_pre2.append(lines.results['fit_peaks_prefactor2']['value'])

print('Fitting {} files took {:.0f}s\n'.format(Nfiles, time.time()-t0))

#Ts = exp.dict['metadata']['sample_temperature_D']
#scan_ids = exp.dict['rawinfo']['scan_id']

# %%
plt.plot(peak_x1, '.-')

# %%
exp.dict['analysis']['circular_average']['fit_peaks_x_center1'] = peak_x1
#exp.dict['analysis']['circular_average']['fit_peaks_x_center2'] = peak_x2
exp.show()

# %%
#Convert list or dict to dataframe:
df_list = pd.DataFrame(peak_x1, columns=['peak_x1'])

# %% [markdown]
# __(Alternatively, other feature extration, e.g. q with max intensity)__

# %%
### Get the q with max intensity within this range

protocol = 'circular_average'
y = []
for ii in np.arange(Nfiles):
    line_plot = DataLine(x = exp.dict['data'][protocol][str(ii)]['q'], y = exp.dict['data'][protocol][str(ii)]['I(q)'])  
    line_x = line_plot.x
    line_y = line_plot.y
    y.append(line_y[idx_min:idx_max])
    
qrange_plot = [1, 1.5] 


Ts = exp.dict['metadata']['sample_temperature_D']
scan_ids = exp.dict['expinfo']['scan_id']

idx_min = int(np.argmin(np.abs(x_axis-qrange_plot[0])))
idx_max = int(np.argmin(np.abs(x_axis-qrange_plot[1])))

x_axis = line_x
q_peakmax_list = []
data_show = []
for ii in np.arange(len(y)):
    line_y = y[ii]
    line_y_crop = line_y[idx_min:idx_max]
    line_x_crop = x_axis[idx_min:idx_max]
    q_peakmax = line_x_crop[np.argmax(line_y_crop)]
    q_peakmax_list.append(q_peakmax)
    data_show.append([Ts[ii], scan_ids[ii], q_peakmax])

df_line_s = pd.DataFrame(q_peakmax_list, columns=['I'])
df_show = pd.DataFrame(data_show, columns = ['RH', 'scan_id', 'q_peakmax'])

print(q_peakmax_list[0:5])

# %% [markdown]
# ##### - __Compare three 1D curves__

# %%
scan_ids = exp.dict['rawinfo']['scan_id']
Ts = exp.dict['metadata']['sample_temperature_D']

labels = ["peak_x1", "temp (degC)"]

fig, ax = plt.subplots()
#fig.subplots_adjust(right=0.75)

twin1 = ax.twinx()
if len(labels)>2:
    twin2 = ax.twinx()
    twin2.spines.right.set_position(("axes", 1.2))


if 1:
    p1, = ax.plot(scan_ids, peak_x1, "b.", label=labels[0])
    p2, = twin1.plot(scan_ids, Ts, "r-", label=labels[1])
    #p3, = twin2.plot(scan_ids, Ts, "g-", label=labels[2])
else:
    p1, = ax.plot(scan_ids, q_peakmax_list, "b-", label="q")
    p2, = twin1.plot(scan_ids, np.array(Ts), "r-", label="Temperature")
    #p3, = twin2.plot([0, 1, 2], [50, 30, 15], "g-", label="Humidity")
    

#ax.set_xlim(0, 2)
#ax.set_ylim(0, 2)
#twin1.set_ylim(0, 4)
#twin2.set_ylim(1, 65)

FS = 12
ax.set_xlabel("scan_id", fontsize=FS)
ax.set_ylabel(labels[0], fontsize=FS)
twin1.set_ylabel(labels[1], fontsize=FS)
if len(labels)>2:
    twin2.set_ylabel(labels[2], fontsize=FS)

ax.yaxis.label.set_color(p1.get_color())
twin1.yaxis.label.set_color(p2.get_color())
if len(labels)>2:
    twin2.yaxis.label.set_color(p3.get_color())

tkw = dict(size=4, width=2, labelsize=15)
ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
twin1.tick_params(axis='y', colors=p2.get_color(), **tkw)
if len(labels)>2:
    twin2.tick_params(axis='y', colors=p3.get_color(), **tkw)
ax.tick_params(axis='x', **tkw)
ax.xaxis.set_major_locator(plt.MaxNLocator(3))


if len(labels)==2:
    ax.legend(handles=[p1, p2], ncols=3, bbox_to_anchor=(1, 1.15))
else:
    ax.legend(handles=[p1, p2, p3], ncols=3, bbox_to_anchor=(1, 1.15))

plt.title(exp.dict['rawinfo']['filename'][0])
plt.show()

# %% [markdown]
# #### &#9642; __Extract 0d feature & Plot 2D map__

# %%
### ROI
if 0:
    reduced_data = exp.dict['data']['roi']
    print('Len(reduced_data) = {}'.format(len(reduced_data)))
    print(reduced_data.keys())

    feature_list = []
    for ii in np.arange(0,len(reduced_data)):
        feature_list.append(reduced_data['stats_average'][ii])

# %%
### Angle

reduced_data = exp.dict['data']['linecut_angle']
print('Len(reduced_data) = {}'.format(len(reduced_data)))

x_pos = exp.dict['metadata']['sample_x']
y_pos = exp.dict['metadata']['sample_y']


feature_list = []
for ii in np.arange(0,len(reduced_data)):
    angle = reduced_data[str(ii)]['q']
    I = reduced_data[str(ii)]['I(q)']
    chi = angle[np.argmax(I)]
    feature_list.append(chi)

# %% [markdown]
# ##### - __Plot scalar 2D mage__

# %%
plt.figure(); plt.clf()

#plt.tripcolor(x_pos, y_pos, feature_list)  
plt.tricontourf(x_pos, y_pos, feature_list, cmap = 'jet') 

plt.colorbar()
plt.xlabel('x'); plt.ylabel('y')
plt.title(exp.dict['expname'])
plt.axis('equal')
plt.axis('tight')

#plt.plot(x_pos, y_pos, 'k.')

# %% [markdown]
# __Plot scalar image with interpolation__

# %%
plot_interp = ['linear', 0.005] 
x_pos_fine, y_pos_fine, feature = Tools.interp_map(x_pos, y_pos, feature_list, plot_interp) 

plt.figure(); 
extent = (np.nanmin(x_pos_fine), np.nanmax(x_pos_fine), np.nanmin(y_pos_fine), np.nanmax(y_pos_fine))

plt.imshow(feature, extent=extent, origin='lower', cmap='jet') #, clim=[-180, 180])  
plt.colorbar()
plt.xlabel('x [mm]'); plt.ylabel('y [mm]')
plt.title(exp.dict['expname'])
plt.axis('equal')
plt.axis('tight')

# %% [markdown]
# ##### - __Plot quiver__

# %%
u_list = []
v_list = []
chi_list = []
for chi in feature_list:
    u = np.cos(np.deg2rad(chi)) 
    v = np.sin(np.deg2rad(chi)) 
    u_list.append(u)
    v_list.append(v)
    chi_list.append(chi)

# %%
fig, ax = plt.subplots(figsize=[10, 6])

q = ax.quiver(x_pos, y_pos, u_list, v_list, chi_list, cmap = 'plasma') #,clim=[0,0.3])

#ax.set_xlim([-0.2,5])
#ax.set_ylim([-0.2,5])
ax.axis('equal')
ax.set_xlabel('$x$ (mm)'); ax.set_ylabel('$y$ (mm)')

cb = plt.colorbar(q)
plt.title(exp.dict['expname'])
# plt.savefig('SAXS mapping_quiver polt_colorbar.png', dpi = 600)

# %% [markdown]
# ### __(5.2) Experiment__

# %% [markdown]
# #### &#9642; __Fitting for experiment__

# %%
curve_1 = exp.dict['metadata']['sample_temperature_D']
curve_2 = exp.dict['analysis']['circular_average']['fit_peaks_x_center1']


plt.plot(curve_1, curve_2, '.-')
#plt.plot(curve_2)

# %%
from SciAnalysis import tools
from SciAnalysis.XSAnalysis.Data import *
#from SciAnalysis.XSAnalysis import Protocols
from SciAnalysis.CurveAnalysis.Data import *

#line_plot = DataLine(x = exp.dict['analysis'][protocol]['q'], y = exp.dict['analysis'][protocol]['I_stack'][file_idx])  
line_plot = DataLineStructuredSort(x = np.asarray(curve_1)*0.1, y = curve_2)

# %%
lm_result, fit_line, fit_line_extended = line_plot.fit_linear(line_plot, **run_args)

# %%
#lm_result

# %%
plt.plot(fit_line.x, fit_line.y, 'b')
#plt.plot(fit_line_extended.x, fit_line_extended.y, 'r:')
print(fit_line.y)

# %% [markdown]
# ## 6. &#9733; Batch Processing
#
# Can be done in background with 'python runXS.py'
#
# (If this section gets stuck for whatever reason, restart the kernal.)

# %%
#EXPR_DIR = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_air_hum50_run2/'

samples = ['EW_PbI2_air_hum0_run6_4V', 
           'EW_PbI2_air_hum25_run1', 'EW_PbI2_air_hum25_run2', 
           'EW_PbI2_air_hum50_run2',
           'EW_PbI2_N2_hum0_run1',
           'EW_PbI2_N2_hum25_run1', 
           'EW_PbI2_N2_hum50_run1', 'EW_PbI2_N2_hum50_run2',           
          ] 
samples = ['EW_FAI0_PbI20_hum25_air_run1',
           'EW_FAI0_PbI20_hum50_air_run1', 'EW_FAI0_PbI250_hum0_air_run1',  'EW_FAI0_PbI250_hum50_air_run1',
           'EW_FAI0_PbI20_hum0_N2_run1',  'EW_FAI0_PbI250_hum0_N2_run1', 
           
           'EW_FAI0_PbI20_hum0_air_run2',
           'EW_FAI0_PbI20_hum0_air_run3', 
           'EW_FAI0_PbI20_hum0_air_run4',
           'EW_FAI0_PbI20_hum0_air_run5',
           'EW_FAI0_PbI20_hum0_air_run6',
           'EW_FAI0_PbI20_hum0_N2_run2',
           'EW_FAI0_PbI220_hum0_N2_run1',        
                    
          ]

stitched = 1


for sample in samples:
    print("====={}=====".format(sample))
    EXPR_DIR = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/' + sample + '/'
    

    if stitched==0:
        source_dir = EXPR_DIR+'/'+DET+'/raw/' 
        output_dir = EXPR_DIR+'/'+DET+'/analysis/'
        #pattern = '*pos1*'
        pattern = '*spin*'
    else:
        source_dir = EXPR_DIR+'/'+DET+'/stitched/'
        output_dir = EXPR_DIR+'/'+DET+'/stitched_analysis/'
        pattern = '*'

    print(source_dir)
    infiles = glob.glob(os.path.join(source_dir, pattern+'.tiff'))
    infiles.sort()

    
    if stitched==1:
        mask = Mask(mask_dir+'Dectris/Pilatus800k2_generic-mask.png')  
    else:
        mask = Mask(mask_dir+'Dectris/Pilatus800k2_gaps-mask.png')
        
    load_args = { 'calibration' : calibration, 
                 'mask' : mask,
                 #'rot180' : False,
                 #'flip' : True, # PSCCD
                 }
    run_args = { 'verbosity' : 3,
                'rcParams': {'axes.labelsize': 25,
                                'xtick.labelsize': 18,
                                'ytick.labelsize': 18,
                                'xtick.major.pad': 5,
                                'ytick.major.pad': 5,
                                },
                }

    process = Protocols.ProcessorXS(load_args=load_args, run_args=run_args)

    # Examples:
    #protocols = [ Protocols.circular_average_q2I(plot_range=[0, 0.2, 0, None]) ]
    #protocols = [ Protocols.linecut_angle(q0=0.01687, dq=0.00455*1.5, show_region=False) ]
    #protocols = [ Protocols.q_image(blur=1.0, bins_relative=0.5, plot_range=[-0.1, 3.0, 0, 3.0], _xticks=[0, 1.0, 2.0, 3.0], ztrim=[0.2, 0.01]) ]
    #protocols = [ Protocols.qr_image(blur=1.0, bins_relative=0.5, plot_range=[-0.1, 3.0, 0, 3.0], _xticks=[0, 1.0, 2.0, 3.0], zmin=1010., ztrim=[None, 0.01]) ]
    #protocols = [ Protocols.qr_image(blur=None, bins_relative=0.8, plot_range=[-0.1, 3.0, 0, 3.0], _xticks=[0, 1.0, 2.0, 3.0], ztrim=[0.38, 0.002], dezing_fill=True) ]
    #protocols = [ Protocols.q_phi_image(bins_relative=0.25, plot_range=[0, 3.0, 0, +90]) ]
    # Protocols.sector_average(angle=-70, dangle=25, show_region=False) 
    # Protocols.qr_image(blur=None, colorbar=True, save_data=False, transparent=False, label_filename=True) 
    # Protocols.linecut_q(chi0= 90+70, dq= .5, gridlines=True, label_filename=True, save_results = [ 'hdf5' ] )
    # Protocols.HDF5(  save_results = [ 'hdf5' ] )
    # Protocols.metadata_extract()

    protocols = [
        #Protocols.HDF5(save_results=['hdf5'])
        #Protocols.calibration_check(show=False, AgBH=True, q0=1.076, dq=0.005, num_rings=10, ztrim=[0.2, 0.01], dpi=300) ,

        Protocols.circular_average(ylog=True, plot_range=[0, None, 0, None], gridlines=True, transparent=False, label_filename=True) ,
        #Protocols.linecut_qr(name='linecut_qr0.025', qz=0.025, dq=0.02, ylog=True, show_region=True, gridlines=True); #dq is half-width
        #Protocols.thumbnails(crop=None, resize=0.5, cmap=cmap_vge, ztrim=[0.06, 0.001], zmin=1000.0) , # PSCCD

        #Protocols.thumbnails(crop=None, resize=0.5, cmap=cmap_vge, ztrim=[0.02, 0.001]) , # Pilatus800k
        #Protocols.thumbnails(name='thumbnails_jet', crop=None, ztrim=[0.06, 0.001]) , # Pilatus800k

        Protocols.qr_image(blur=None, colorbar=True, save_data=False, transparent=False, label_filename=True, plot_buffers = [0.1, 0.1, 0.1, 0.1]),    
        #Protocols.q_image(blur=None, colorbar=True, save_data=False, transparent=False, label_filename=True, plot_buffers = [0.2, 0.1, 0.2, 0.1], dpi=200) 
        #Protocols.linecut_qr(ylog=True, name='linecut_qr_qz0.03', qz=0.03, dq=0.02, show_region='save', label_filename=True, gridlines=True),
        ]

    # To stitch files: 
    # 1) run stitch.py to stitch into .TIFF 
    # 2) run runStitched.py to generate thumbnails etc

    # Run
    ########################################
    print('Processing {} infiles...'.format(len(infiles)))
    process.run(infiles, protocols, output_dir=output_dir, force= 1)

    print('Done!')

    # Loop
    ########################################
    # This is typically only used at the beamline (it loops forever, watching for new files).
    #process.monitor_loop(source_dir=source_dir, pattern=pattern+'*.tiff', protocols=protocols, output_dir=output_dir, force=False)
# Out:
# =====EW_FAI0_PbI20_hum25_air_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/stitched/
# Processing 10 infiles...
# Running circular_average for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1033.4s_RH22.631_x-0.001_th0.050_5.00s_1343078_maxs_stitched
# /nsls2/data/cms/legacy/xf11bm/software/SciAnalysis/SciAnalysis/XSAnalysis/Data.py:441: RuntimeWarning: invalid value encountered in sqrt
#   I_err_shot = np.sqrt(I_vals)[idx]/num_per_bin[idx]
# /nsls2/data/cms/legacy/xf11bm/software/SciAnalysis/SciAnalysis/Data.py:452: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   self.ax.axis( [xi, xf, yi, yf] )
# Running qr_image for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1033.4s_RH22.631_x-0.001_th0.050_5.00s_1343078_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1041.3s_RH22.063_x-0.001_th0.100_5.00s_1343079_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1041.3s_RH22.063_x-0.001_th0.100_5.00s_1343079_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1048.3s_RH22.158_x-0.001_th0.150_5.00s_1343080_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1048.3s_RH22.158_x-0.001_th0.150_5.00s_1343080_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1056.4s_RH22.894_x-0.001_th0.200_5.00s_1343081_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1056.4s_RH22.894_x-0.001_th0.200_5.00s_1343081_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1063.8s_RH23.262_x-0.001_th0.250_5.00s_1343082_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1063.8s_RH23.262_x-0.001_th0.250_5.00s_1343082_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1070.8s_RH22.494_x-0.001_th0.300_5.00s_1343083_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1070.8s_RH22.494_x-0.001_th0.300_5.00s_1343083_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1078.1s_RH22.252_x-0.001_th0.350_5.00s_1343084_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1078.1s_RH22.252_x-0.001_th0.350_5.00s_1343084_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1084.9s_RH22.305_x-0.001_th0.400_5.00s_1343085_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1084.9s_RH22.305_x-0.001_th0.400_5.00s_1343085_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1091.8s_RH22.494_x-0.001_th0.450_5.00s_1343086_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1091.8s_RH22.494_x-0.001_th0.450_5.00s_1343086_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1098.7s_RH21.453_x-0.001_th0.500_5.00s_1343087_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum25_air_run1_static_pos1_1098.7s_RH21.453_x-0.001_th0.500_5.00s_1343087_maxs_stitched
# Done!
# =====EW_FAI0_PbI20_hum50_air_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/stitched/
# Processing 10 infiles...
# Running circular_average for EW_FAI0_PbI20_hum50_air_run1_static_pos1_913.6s_RH50.354_x-0.001_th0.050_5.00s_1343116_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum50_air_run1_static_pos1_913.6s_RH50.354_x-0.001_th0.050_5.00s_1343116_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum50_air_run1_static_pos1_921.8s_RH50.870_x-0.001_th0.100_5.00s_1343117_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum50_air_run1_static_pos1_921.8s_RH50.870_x-0.001_th0.100_5.00s_1343117_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum50_air_run1_static_pos1_928.9s_RH51.091_x-0.001_th0.150_5.00s_1343118_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum50_air_run1_static_pos1_928.9s_RH51.091_x-0.001_th0.150_5.00s_1343118_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum50_air_run1_static_pos1_935.7s_RH51.133_x-0.001_th0.200_5.00s_1343119_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum50_air_run1_static_pos1_935.7s_RH51.133_x-0.001_th0.200_5.00s_1343119_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum50_air_run1_static_pos1_943.1s_RH50.744_x-0.001_th0.250_5.00s_1343120_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum50_air_run1_static_pos1_943.1s_RH50.744_x-0.001_th0.250_5.00s_1343120_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum50_air_run1_static_pos1_950.1s_RH50.007_x-0.001_th0.300_5.00s_1343121_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum50_air_run1_static_pos1_950.1s_RH50.007_x-0.001_th0.300_5.00s_1343121_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum50_air_run1_static_pos1_956.9s_RH50.733_x-0.001_th0.350_5.00s_1343122_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum50_air_run1_static_pos1_956.9s_RH50.733_x-0.001_th0.350_5.00s_1343122_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum50_air_run1_static_pos1_964.1s_RH50.260_x-0.001_th0.400_5.00s_1343123_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum50_air_run1_static_pos1_964.1s_RH50.260_x-0.001_th0.400_5.00s_1343123_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum50_air_run1_static_pos1_971.2s_RH52.637_x-0.001_th0.450_5.00s_1343124_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum50_air_run1_static_pos1_971.2s_RH52.637_x-0.001_th0.450_5.00s_1343124_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum50_air_run1_static_pos1_978.3s_RH51.543_x-0.001_th0.500_5.00s_1343125_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum50_air_run1_static_pos1_978.3s_RH51.543_x-0.001_th0.500_5.00s_1343125_maxs_stitched
# Done!
# =====EW_FAI0_PbI250_hum0_air_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/stitched/
# Processing 10 infiles...
# Running circular_average for EW_FAI0_PbI250_hum0_air_run1_static_pos1_633.4s_RH1.207_x-0.001_th0.050_5.00s_1343154_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_air_run1_static_pos1_633.4s_RH1.207_x-0.001_th0.050_5.00s_1343154_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_air_run1_static_pos1_641.9s_RH1.891_x-0.001_th0.100_5.00s_1343155_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_air_run1_static_pos1_641.9s_RH1.891_x-0.001_th0.100_5.00s_1343155_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_air_run1_static_pos1_648.9s_RH1.459_x-0.001_th0.150_5.00s_1343156_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_air_run1_static_pos1_648.9s_RH1.459_x-0.001_th0.150_5.00s_1343156_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_air_run1_static_pos1_656.0s_RH3.584_x-0.001_th0.200_5.00s_1343157_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_air_run1_static_pos1_656.0s_RH3.584_x-0.001_th0.200_5.00s_1343157_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_air_run1_static_pos1_663.1s_RH1.533_x-0.001_th0.250_5.00s_1343158_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_air_run1_static_pos1_663.1s_RH1.533_x-0.001_th0.250_5.00s_1343158_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_air_run1_static_pos1_670.2s_RH0.723_x-0.001_th0.300_5.00s_1343159_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_air_run1_static_pos1_670.2s_RH0.723_x-0.001_th0.300_5.00s_1343159_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_air_run1_static_pos1_677.1s_RH1.281_x-0.001_th0.350_5.00s_1343160_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_air_run1_static_pos1_677.1s_RH1.281_x-0.001_th0.350_5.00s_1343160_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_air_run1_static_pos1_683.9s_RH1.722_x-0.001_th0.400_5.00s_1343161_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_air_run1_static_pos1_683.9s_RH1.722_x-0.001_th0.400_5.00s_1343161_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_air_run1_static_pos1_690.7s_RH1.523_x-0.001_th0.450_5.00s_1343162_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_air_run1_static_pos1_690.7s_RH1.523_x-0.001_th0.450_5.00s_1343162_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_air_run1_static_pos1_697.7s_RH0.955_x-0.001_th0.500_5.00s_1343163_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_air_run1_static_pos1_697.7s_RH0.955_x-0.001_th0.500_5.00s_1343163_maxs_stitched
# Done!
# =====EW_FAI0_PbI250_hum50_air_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/stitched/
# Processing 10 infiles...
# Running circular_average for EW_FAI0_PbI250_hum50_air_run1_static_pos1_675.9s_RH50.765_x-0.001_th0.050_5.00s_1343192_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum50_air_run1_static_pos1_675.9s_RH50.765_x-0.001_th0.050_5.00s_1343192_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum50_air_run1_static_pos1_683.9s_RH51.133_x-0.001_th0.100_5.00s_1343193_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum50_air_run1_static_pos1_683.9s_RH51.133_x-0.001_th0.100_5.00s_1343193_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum50_air_run1_static_pos1_690.8s_RH51.290_x-0.001_th0.150_5.00s_1343194_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum50_air_run1_static_pos1_690.8s_RH51.290_x-0.001_th0.150_5.00s_1343194_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum50_air_run1_static_pos1_697.9s_RH51.711_x-0.001_th0.200_5.00s_1343195_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum50_air_run1_static_pos1_697.9s_RH51.711_x-0.001_th0.200_5.00s_1343195_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum50_air_run1_static_pos1_704.8s_RH53.289_x-0.001_th0.250_5.00s_1343196_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum50_air_run1_static_pos1_704.8s_RH53.289_x-0.001_th0.250_5.00s_1343196_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum50_air_run1_static_pos1_712.0s_RH51.501_x-0.001_th0.300_5.00s_1343197_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum50_air_run1_static_pos1_712.0s_RH51.501_x-0.001_th0.300_5.00s_1343197_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum50_air_run1_static_pos1_719.2s_RH51.038_x-0.001_th0.350_5.00s_1343198_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum50_air_run1_static_pos1_719.2s_RH51.038_x-0.001_th0.350_5.00s_1343198_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum50_air_run1_static_pos1_726.1s_RH50.912_x-0.001_th0.400_5.00s_1343199_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum50_air_run1_static_pos1_726.1s_RH50.912_x-0.001_th0.400_5.00s_1343199_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum50_air_run1_static_pos1_733.2s_RH52.353_x-0.001_th0.450_5.00s_1343200_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum50_air_run1_static_pos1_733.2s_RH52.353_x-0.001_th0.450_5.00s_1343200_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum50_air_run1_static_pos1_740.1s_RH50.796_x-0.001_th0.500_5.00s_1343201_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum50_air_run1_static_pos1_740.1s_RH50.796_x-0.001_th0.500_5.00s_1343201_maxs_stitched
# Done!
# =====EW_FAI0_PbI20_hum0_N2_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/stitched/
# Processing 10 infiles...
# Running circular_average for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_632.7s_RH1.638_x-0.001_th0.050_5.00s_1343230_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_632.7s_RH1.638_x-0.001_th0.050_5.00s_1343230_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_640.8s_RH1.260_x-0.001_th0.100_5.00s_1343231_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_640.8s_RH1.260_x-0.001_th0.100_5.00s_1343231_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_647.8s_RH0.828_x-0.001_th0.150_5.00s_1343232_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_647.8s_RH0.828_x-0.001_th0.150_5.00s_1343232_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_654.7s_RH2.101_x-0.001_th0.200_5.00s_1343233_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_654.7s_RH2.101_x-0.001_th0.200_5.00s_1343233_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_661.6s_RH3.058_x-0.001_th0.250_5.00s_1343234_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_661.6s_RH3.058_x-0.001_th0.250_5.00s_1343234_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_668.9s_RH1.838_x-0.001_th0.300_5.00s_1343235_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_668.9s_RH1.838_x-0.001_th0.300_5.00s_1343235_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_675.7s_RH1.123_x-0.001_th0.350_5.00s_1343236_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_675.7s_RH1.123_x-0.001_th0.350_5.00s_1343236_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_682.8s_RH2.795_x-0.001_th0.400_5.00s_1343237_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_682.8s_RH2.795_x-0.001_th0.400_5.00s_1343237_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_689.7s_RH1.859_x-0.001_th0.450_5.00s_1343238_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_689.7s_RH1.859_x-0.001_th0.450_5.00s_1343238_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_696.9s_RH1.785_x-0.001_th0.500_5.00s_1343239_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_N2_run1_static_pos1_696.9s_RH1.785_x-0.001_th0.500_5.00s_1343239_maxs_stitched
# Done!
# =====EW_FAI0_PbI250_hum0_N2_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/stitched/
# Processing 10 infiles...
# Running circular_average for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_622.2s_RH1.070_x-0.001_th0.050_5.00s_1343268_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_622.2s_RH1.070_x-0.001_th0.050_5.00s_1343268_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_630.0s_RH1.565_x-0.001_th0.100_5.00s_1343269_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_630.0s_RH1.565_x-0.001_th0.100_5.00s_1343269_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_636.9s_RH0.955_x-0.001_th0.150_5.00s_1343270_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_636.9s_RH0.955_x-0.001_th0.150_5.00s_1343270_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_643.8s_RH2.732_x-0.001_th0.200_5.00s_1343271_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_643.8s_RH2.732_x-0.001_th0.200_5.00s_1343271_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_650.6s_RH3.321_x-0.001_th0.250_5.00s_1343272_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_650.6s_RH3.321_x-0.001_th0.250_5.00s_1343272_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_657.5s_RH0.439_x-0.001_th0.300_5.00s_1343273_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_657.5s_RH0.439_x-0.001_th0.300_5.00s_1343273_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_664.9s_RH0.923_x-0.001_th0.350_5.00s_1343274_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_664.9s_RH0.923_x-0.001_th0.350_5.00s_1343274_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_672.0s_RH1.985_x-0.001_th0.400_5.00s_1343275_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_672.0s_RH1.985_x-0.001_th0.400_5.00s_1343275_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_678.8s_RH1.680_x-0.001_th0.450_5.00s_1343276_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_678.8s_RH1.680_x-0.001_th0.450_5.00s_1343276_maxs_stitched
# Running circular_average for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_685.6s_RH1.491_x-0.001_th0.500_5.00s_1343277_maxs_stitched
# Running qr_image for EW_FAI0_PbI250_hum0_N2_run1_static_pos1_685.6s_RH1.491_x-0.001_th0.500_5.00s_1343277_maxs_stitched
# Done!
# =====EW_FAI0_PbI20_hum0_air_run2=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/stitched/
# Processing 10 infiles...
# Running circular_average for EW_FAI0_PbI20_hum0_air_run2_static_pos1_682.7s_RH2.206_x-0.001_th0.050_5.00s_1343308_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_air_run2_static_pos1_682.7s_RH2.206_x-0.001_th0.050_5.00s_1343308_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_air_run2_static_pos1_690.7s_RH0.513_x-0.001_th0.100_5.00s_1343309_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_air_run2_static_pos1_690.7s_RH0.513_x-0.001_th0.100_5.00s_1343309_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_air_run2_static_pos1_697.8s_RH0.618_x-0.001_th0.150_5.00s_1343310_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_air_run2_static_pos1_697.8s_RH0.618_x-0.001_th0.150_5.00s_1343310_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_air_run2_static_pos1_704.9s_RH1.491_x-0.001_th0.200_5.00s_1343311_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_air_run2_static_pos1_704.9s_RH1.491_x-0.001_th0.200_5.00s_1343311_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_air_run2_static_pos1_712.3s_RH0.134_x-0.001_th0.250_5.00s_1343312_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_air_run2_static_pos1_712.3s_RH0.134_x-0.001_th0.250_5.00s_1343312_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_air_run2_static_pos1_719.4s_RH2.417_x-0.001_th0.300_5.00s_1343313_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_air_run2_static_pos1_719.4s_RH2.417_x-0.001_th0.300_5.00s_1343313_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_air_run2_static_pos1_726.7s_RH1.901_x-0.001_th0.350_5.00s_1343314_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_air_run2_static_pos1_726.7s_RH1.901_x-0.001_th0.350_5.00s_1343314_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_air_run2_static_pos1_733.7s_RH2.048_x-0.001_th0.400_5.00s_1343315_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_air_run2_static_pos1_733.7s_RH2.048_x-0.001_th0.400_5.00s_1343315_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_air_run2_static_pos1_740.8s_RH0.544_x-0.001_th0.450_5.00s_1343316_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_air_run2_static_pos1_740.8s_RH0.544_x-0.001_th0.450_5.00s_1343316_maxs_stitched
# Running circular_average for EW_FAI0_PbI20_hum0_air_run2_static_pos1_747.8s_RH2.017_x-0.001_th0.500_5.00s_1343317_maxs_stitched
# Running qr_image for EW_FAI0_PbI20_hum0_air_run2_static_pos1_747.8s_RH2.017_x-0.001_th0.500_5.00s_1343317_maxs_stitched
# Done!
# =====EW_FAI0_PbI20_hum0_air_run3=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run3//maxs/stitched/
# Processing 0 infiles...
# Done!
# =====EW_FAI0_PbI20_hum0_air_run4=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run4//maxs/stitched/
# Processing 0 infiles...
# Done!
# =====EW_FAI0_PbI20_hum0_air_run5=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run5//maxs/stitched/
# Processing 0 infiles...
# Done!
# =====EW_FAI0_PbI20_hum0_air_run6=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run6//maxs/stitched/
# Processing 0 infiles...
# Done!
# =====EW_FAI0_PbI20_hum0_N2_run2=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run2//maxs/stitched/
# Processing 0 infiles...
# Done!
# =====EW_FAI0_PbI220_hum0_N2_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI220_hum0_N2_run1//maxs/stitched/
# Processing 0 infiles...
# Done!

# %% [markdown]
# ### __! Custom Routine__

# %%
### Specify directory, detector, and files of interest
# Spin-coating
samples = ['EW_PbI2_air_hum0_run6_4V', 
           'EW_PbI2_air_hum25_run1', 'EW_PbI2_air_hum25_run2', 
           'EW_PbI2_air_hum50_run2',
           'EW_PbI2_N2_hum0_run1',
           'EW_PbI2_N2_hum25_run1', 
           'EW_PbI2_N2_hum50_run1', 'EW_PbI2_N2_hum50_run2',           
          ] 

# Spin-coating with Injection
# samples = ['EW_FAI0_PbI20_hum25_air_run1',
#            'EW_FAI0_PbI20_hum50_air_run1', 'EW_FAI0_PbI250_hum0_air_run1',  'EW_FAI0_PbI250_hum50_air_run1',
#            'EW_FAI0_PbI20_hum0_N2_run1',  'EW_FAI0_PbI250_hum0_N2_run1', 
           
#            'EW_FAI0_PbI20_hum0_air_run2',
#            'EW_FAI0_PbI20_hum0_air_run3', 
#            'EW_FAI0_PbI20_hum0_air_run4',
#            'EW_FAI0_PbI20_hum0_air_run5',
#            'EW_FAI0_PbI20_hum0_air_run6',
#            'EW_FAI0_PbI20_hum0_N2_run2',
#            'EW_FAI0_PbI220_hum0_N2_run1',        
                    
#           ]

USER_DIR = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/'
Out_dir = USER_DIR + '/Summary/'

for sample in samples:
    print("====={}=====".format(sample))
    EXPR_DIR = USER_DIR + sample + '/'
    exp = Experiment.experiment(sample, folder=EXPR_DIR, det='maxs', beamline='None') ##Experiment name: rbitrary or related to the sample name
    #exp.dict['expinfo']['fn_patterns'] = ['*' + sample + '_*5.00*'] #['SM_thermals4_*30.00*'] #['SC*CS*pos1*th0.15*'] #['SC*FP1**RPM3*T30*V18*pos1*th0*']  
    exp.dict['expinfo']['fn_patterns'] = ['*spin*']

    ### Load files
    try:
        for pattern in exp.dict['expinfo']['fn_patterns']:
            #exp.defFiles_query(fn='PBG', folder=EXPR_DIR, scanid = [900000, 1200000], verbose=1) 
            exp.defFiles(fn=pattern, verbose=1) 
            #exp.defFiles(fn=pattern, scanid = [750000, 900000], verbose=1)  

        infiles = exp.dict['rawinfo']['filename']
        Nfiles = len(infiles)

    except:
        print('\n!!! Databroker not working, loading files directly.')
        #exp.dict['expinfo']['beamline'] = None
        for pattern in exp.dict['expinfo']['fn_patterns']:
            exp.defFiles(fn=pattern, verbose=1)    
    
    ### Specify beamline config (e.g. beam energy, center, det-sample distance)
    if 1:
        calibration = Calibration(wavelength_A=0.9184) #13.5 keV
        calibration.set_image_size(981, height=1043) # Pilatus1M
        calibration.set_pixel_size(pixel_size_um=172.0)
        calibration.set_beam_position(555, 1043-392)  #2024-C1 Loo
        calibration.set_distance(0.212)

        mask_dir = SciAnalysis_PATH + '/SciAnalysis/XSAnalysis/masks/'
        mask = Mask(mask_dir+'Dectris/Pilatus800k_gaps-mask.png')

    else:
        calibration = Calibration(wavelength_A=0.9184) # 13.5 keV
        calibration.set_image_size(1475, height=1679) # Pilatus2M
        calibration.set_pixel_size(pixel_size_um=172.0)

        calibration.set_beam_position(757, 1679-601) # SAXSx -65, SAXSy -73    
        calibration.set_distance(5.03)    

        flag_stitch = 0
        mask_dir = SciAnalysis_PATH + '/SciAnalysis/XSAnalysis/masks/'
        if flag_stitch:
            mask = Mask(mask_dir+'Dectris/Pilatus2M_vertical_gaps-mask.png')
        else:
            mask = Mask(mask_dir+'Dectris/Pilatus2M_gaps-mask.png')
        mask.load(EXPR_DIR+'saxs/analysis/mask_5m.png')  
    
    
    load_args = { 'calibration' : calibration, 
                 'mask' : mask,
                 #'rot180' : False,
                 #'flip' : True, # PSCCD
                 }
    run_args = { 'verbosity' : 3,
                #'save_results' : ['xml', 'plots', 'txt', 'hdf5'],
                }
    process = Protocols.ProcessorXS(load_args=load_args, run_args=run_args)
    #infiles = exp.dict['expinfo']['filename']


    ### Run analysis 
    protocols = ['circular_average'] #['linecut_angle'] #['circular_average'] #, 'sector_average', 'linecut_qz']
    exp.dict['analysis']['cali'] = [calibration.wavelength_A, calibration.x0, calibration.y0, calibration.distance_m]

    t0 = time.time()  

    line_y_stack = []
    for protocol in protocols:
        if 'circular_average' in protocol:
            for ii, infile in enumerate(infiles):
                if np.mod(ii+1, 50)==0: print('[{:.0f}%]'.format(ii/Nfiles*100))

                det = exp.dict['expinfo']['det']
                folder = exp.dict['expinfo']['folder']

                infile_fullpath = folder+'/'+det+'/raw/'+exp.dict['rawinfo']['filename'][ii]+'_'+det+'.tiff'
                data = process.load(infile_fullpath, calibration=calibration, mask=mask, run_args=run_args)

                ### Run the protocol
                line_output = data.circular_average_q_bin(error=False)
                line_y_stack.append(line_output.y)

            ### Save analysis to exp.dict
            if 1:
                exp.dict['analysis'][protocol] = {}
                exp.dict['analysis'][protocol]['q'] = line_output.x
                exp.dict['analysis'][protocol]['I_stack'] = line_y_stack   


        print('Done! (Analysis took {:.0f}s)\n'.format(time.time()-t0))

        now = datetime.datetime.now()
        dt_string = now.strftime("%Y/%m/%d %H:%M:%S")
        print("{}\n".format(dt_string))

        print(exp.dict['analysis'].keys())
        
    ###### Save to H5
    h5_path = EXPR_DIR+"/data/"
    h5_file = str(exp.dict['expinfo']['expname']) + '_cms_MAXS.h5'
    output_file = h5_path+h5_file        
    dicttoh5(exp.dict, output_file)
    print('Experiment saved as {}'.format(output_file))
    
    h5_path = Out_dir
    h5_file = str(exp.dict['expinfo']['expname']) + '_cms_MAXS.h5'
    output_file = h5_path+h5_file        
    dicttoh5(exp.dict, output_file)
    print('Experiment saved as {}'.format(output_file))
    
    
    ####### e.g. Copy from Section 5.1 Plot Curves 
    q_label = [] #[1.278, 1.88, 2.219, 2.564, 2.905]; # Label the lines
    flag_log = [1, 0]

    #protocol = 'circular_average'
    protocol = list(exp.dict['analysis'].keys())[-1]

    x_axis = exp.dict['analysis'][protocol]['q'] 
    I_stack = exp.dict['analysis'][protocol]['I_stack']
    if flag_log[0]:
        I_stack = np.log(I_stack)

    idx0 = 40 

    # %matplotlib inline
    plt.figure(2, figsize=(12,8)); plt.clf()
    ax = plt.gca()
    plt.imshow(I_stack[:, idx0:], origin='lower', cmap='jet', extent = [np.min(x_axis[idx0:]), np.max(x_axis), 0, I_stack.shape[0]],  aspect='auto') #aspect='auto' 0.005
    cbar = plt.colorbar(fraction=0.02, pad=0.02, aspect=40) 
    filename = exp.dict['rawinfo']['filename'][0]
    plt.title(filename)
    plt.xlabel('q (A^-1)')
    plt.ylabel('file index')

    if 1:
        #Ts = exp.dict['metadata']['sample_temperature_D'] 
        idx_array = np.arange(0, I_stack.shape[0], 60).astype(int)
        ylabel_array = []
        for idx in idx_array:
            ylabel_array.append(np.round(idx/2/60,1))
        ax.set_yticks(idx_array)
        ax.set_yticklabels(ylabel_array)
        plt.ylabel('min.')

    print('q_label = {}'.format(q_label))
    for q in q_label:
        plt.plot([q, q], [0, I_stack.shape[0]], 'k',  alpha=0.2)
    
    ## Save
    plt.savefig(str(exp.dict['expinfo']['folder']) + 'data/' + str(exp.dict['expinfo']['expname'])+'2d.png')
    plt.savefig(Out_dir + str(exp.dict['expinfo']['expname'])+'_2d.png')


    ####### e.g. Copy from Section 5.1
    # %matplotlib inline
    plt.figure(1, figsize=(8, 8)); plt.clf()
    Nfiles = len(exp.dict['rawinfo']['filename'])
    infile = exp.dict['rawinfo']['filename'][0]

    qrange_plot = [0.3, 3.6] #[0.08, 0.12] ###
    q_label = []; q_peaks #[1.278, 1.88, 2.219, 2.564, 2.905]; # Label the lines

    cmap = mpl.colormaps['jet'] #viridis, jet, hsv, brg
    colors = cmap(np.linspace(0.0, 1.0, Nfiles))
    flag_log = [1, 0]

    #sample_temperature_D = exp.dict['metadata']['sample_temperature_D']
    scan_ids = exp.dict['rawinfo']['scan_id']
    filenames = exp.dict['rawinfo']['filename']

    ### Plot
    protocol = 'circular_average'
    x_axis = exp.dict['analysis'][protocol]['q'] 
    idx_min = int(np.argmin(np.abs(x_axis-qrange_plot[0])))
    idx_max = int(np.argmin(np.abs(x_axis-qrange_plot[1])))

    I_stack = exp.dict['analysis'][protocol]['I_stack']
    spacing_plot = 0.002 #arbitrary

    if flag_log[0]:
        I_stack = np.log(I_stack)

    st_legend = []
    if 0:
        for ii, filename in zip(np.arange(Nfiles), filenames):
            #print('{}:, {}'.format(ii, filename))
            color = colors[ii]
            linestyle = None
            if 'T34' in filename or 'T33' in filename: #or 'x0.0' in filename:
                linestyle = ':'       

            plt.plot((x_axis[idx_min:idx_max]),I_stack[ii][idx_min:idx_max], linestyle=linestyle, color=color, label=str(ii)+': '+filename[0:filename.find('pos1')]) #label=filename[0:filename.find('pos1')   
            st_legend.append(filename)

    if 1:
        for ii, filename in zip(np.arange(Nfiles), filenames):
            #print('{}:, {}'.format(ii, filename))
            color = colors[ii]
            linestyle = None

            plt.plot((x_axis[idx_min:idx_max]),I_stack[ii][idx_min:idx_max]+ii*spacing_plot+spacing_plot*5, linestyle=linestyle, color=color, label=str(ii)+': '+filename[0:filename.find('pos1')]) #label=filename[0:filename.find('pos1')
            #plt.plot((x_axis[idx_min:idx_max]),I_stack[ii][idx_min:idx_max]+ii*spacing_plot+spacing_plot*5+offset, linestyle=linestyle, color=color, label=str(ii)+': '+filename[0:filename.find('pos1')]) #label=filename[0:filename.find('pos1')
            #plt.plot(np.log10(x_axis),I_stack[ii]+ii*spacing_plot, linestyle=linestyle, color=color, label=str(ii)+': '+filename[0:filename.find('pos1')]) #label=filename[0:filename.find('pos1')

            #if np.mod(ii,5)==0:
            #    plt.text(x_axis[idx_min], I_stack[ii][idx_min]+ii*spacing_plot, str(ii))
            #plt.grid('minor')
            #st_legend.append(filename)
            plt.ylabel('Intensity (shifted)')

    for q in q_label:
        plt.plot([q, q], [min(I_stack[0])*0.8, max(I_stack[0])*1.2+Nfiles*spacing_plot], 'k',  alpha=0.2)   

    plt.legend(st_legend, fontsize=8, ncols=1, bbox_to_anchor=(1.01, 1.01)) 
    plt.title('{}, \nN={}, spacing_plot={}'.format(infile.split('raw')[-1], Nfiles, spacing_plot))
    plt.grid()
    
    ## Save
    plt.savefig(str(exp.dict['expinfo']['folder']) + 'data/' + str(exp.dict['expinfo']['expname'])+'.png')
    plt.savefig(Out_dir + str(exp.dict['expinfo']['expname'])+'_waterfall.png')\
# Out:
# =====EW_PbI2_air_hum0_run6_4V=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_air_hum0_run6_4V/maxs/raw/
# Loading 600 files
# Sorting files by scanid
# CMS
# Loaded 600 files.
# (defFiles time = 0.0s)
# [8%]
# [16%]
# [25%]
# [33%]
# [42%]
# [50%]
# [58%]
# [66%]
# [75%]
# [83%]
# [92%]
# [100%]
# Done! (Analysis took 101s)
#
# 2024/01/26 15:41:45
#
# dict_keys(['cali', 'circular_average'])
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_air_hum0_run6_4V//data/EW_PbI2_air_hum0_run6_4V_cms_MAXS.h5
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo//Summary/EW_PbI2_air_hum0_run6_4V_cms_MAXS.h5
# q_label = []
# /tmp/ipykernel_1969090/886182797.py:153: RuntimeWarning: invalid value encountered in log
#   I_stack = np.log(I_stack)
# /tmp/ipykernel_1969090/886182797.py:213: RuntimeWarning: invalid value encountered in log
#   I_stack = np.log(I_stack)
# =====EW_PbI2_air_hum25_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_air_hum25_run1/maxs/raw/
# Loading 600 files
# Sorting files by scanid
# CMS
# Loaded 600 files.
# (defFiles time = 0.0s)
# [8%]
# [16%]
# [25%]
# [33%]
# [42%]
# [50%]
# [58%]
# [66%]
# [75%]
# [83%]
# [92%]
# [100%]
# Done! (Analysis took 97s)
#
# 2024/01/26 15:43:24
#
# dict_keys(['cali', 'circular_average'])
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_air_hum25_run1//data/EW_PbI2_air_hum25_run1_cms_MAXS.h5
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo//Summary/EW_PbI2_air_hum25_run1_cms_MAXS.h5
# q_label = []
# =====EW_PbI2_air_hum25_run2=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_air_hum25_run2/maxs/raw/
# Loading 600 files
# Sorting files by scanid
# CMS
# Loaded 600 files.
# (defFiles time = 0.0s)
# [8%]
# [16%]
# [25%]
# [33%]
# [42%]
# [50%]
# [58%]
# [66%]
# [75%]
# [83%]
# [92%]
# [100%]
# Done! (Analysis took 97s)
#
# 2024/01/26 15:45:04
#
# dict_keys(['cali', 'circular_average'])
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_air_hum25_run2//data/EW_PbI2_air_hum25_run2_cms_MAXS.h5
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo//Summary/EW_PbI2_air_hum25_run2_cms_MAXS.h5
# q_label = []
# =====EW_PbI2_air_hum50_run2=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_air_hum50_run2/maxs/raw/
# Loading 600 files
# Sorting files by scanid
# CMS
# Loaded 600 files.
# (defFiles time = 0.0s)
# [8%]
# [16%]
# [25%]
# [33%]
# [42%]
# [50%]
# [58%]
# [66%]
# [75%]
# [83%]
# [92%]
# [100%]
# Done! (Analysis took 99s)
#
# 2024/01/26 15:46:45
#
# dict_keys(['cali', 'circular_average'])
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_air_hum50_run2//data/EW_PbI2_air_hum50_run2_cms_MAXS.h5
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo//Summary/EW_PbI2_air_hum50_run2_cms_MAXS.h5
# q_label = []
# =====EW_PbI2_N2_hum0_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_N2_hum0_run1/maxs/raw/
# Loading 600 files
# Sorting files by scanid
# CMS
# Loaded 600 files.
# (defFiles time = 0.0s)
# [8%]
# [16%]
# [25%]
# [33%]
# [42%]
# [50%]
# [58%]
# [66%]
# [75%]
# [83%]
# [92%]
# [100%]
# Done! (Analysis took 101s)
#
# 2024/01/26 15:48:29
#
# dict_keys(['cali', 'circular_average'])
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_N2_hum0_run1//data/EW_PbI2_N2_hum0_run1_cms_MAXS.h5
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo//Summary/EW_PbI2_N2_hum0_run1_cms_MAXS.h5
# q_label = []
# =====EW_PbI2_N2_hum25_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_N2_hum25_run1/maxs/raw/
# Loading 600 files
# Sorting files by scanid
# CMS
# Loaded 600 files.
# (defFiles time = 0.0s)
# [8%]
# [16%]
# [25%]
# [33%]
# [42%]
# [50%]
# [58%]
# [66%]
# [75%]
# [83%]
# [92%]
# [100%]
# Done! (Analysis took 103s)
#
# 2024/01/26 15:50:15
#
# dict_keys(['cali', 'circular_average'])
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_N2_hum25_run1//data/EW_PbI2_N2_hum25_run1_cms_MAXS.h5
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo//Summary/EW_PbI2_N2_hum25_run1_cms_MAXS.h5
# q_label = []
# =====EW_PbI2_N2_hum50_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_N2_hum50_run1/maxs/raw/
# Loading 600 files
# Sorting files by scanid
# CMS
# Loaded 600 files.
# (defFiles time = 0.0s)
# [8%]
# [16%]
# [25%]
# [33%]
# [42%]
# [50%]
# [58%]
# [66%]
# [75%]
# [83%]
# [92%]
# [100%]
# Done! (Analysis took 94s)
#
# 2024/01/26 15:51:51
#
# dict_keys(['cali', 'circular_average'])
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_N2_hum50_run1//data/EW_PbI2_N2_hum50_run1_cms_MAXS.h5
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo//Summary/EW_PbI2_N2_hum50_run1_cms_MAXS.h5
# q_label = []
# =====EW_PbI2_N2_hum50_run2=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_N2_hum50_run2/maxs/raw/
# Loading 600 files
# Sorting files by scanid
# CMS
# Loaded 600 files.
# (defFiles time = 0.0s)
# [8%]
# [16%]
# [25%]
# [33%]
# [42%]
# [50%]
# [58%]
# [66%]
# [75%]
# [83%]
# [92%]
# [100%]
# Done! (Analysis took 92s)
#
# 2024/01/26 15:53:25
#
# dict_keys(['cali', 'circular_average'])
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_PbI2_N2_hum50_run2//data/EW_PbI2_N2_hum50_run2_cms_MAXS.h5
# Experiment saved as /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo//Summary/EW_PbI2_N2_hum50_run2_cms_MAXS.h5
# q_label = []

# %% [markdown]
# ## 7. Stitching
#
# Take multiple data at different detector positions to fill in the detector module gaps.
#
# (Originally in /nsls2/data/cms/legacy/xf11bm/software/StitchPilatus/)

# %%
import numpy as np
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt

from PIL import Image 

import sys, os
import glob

# %% [markdown]
# #### &#9642; __Pilatus2M__

# %%
#mask session
mask_folder = '/nsls2/data/cms/legacy/xf11bm/software/SciAnalysis/SciAnalysis/XSAnalysis/masks/'
mask = mask_folder + 'Dectris/Pilatus2M_gaps-mask.png'

mask1 = Image.open(mask).convert('I') # 'I' : 32-bit integer pixels
mask1_data = np.copy( np.asarray(mask1))
mask1_data = mask1_data/np.max(mask1_data)

mask_black = Image.new('L', (1475,1679), 'black')

#mask2
mask2_new = Image.new('I', (1475,1679), 'white')

#mask2 = mask1
mask2_cut = mask1.crop((0, 30 ,1475, 1679 ))
mask2_new.paste(mask2_cut)
mask2_black = mask_black.crop((0,  1679 -30 ,1475,1679 ))
mask2_new.paste(mask2_black, [0,  1679 -30])
mask2_new = mask2_new/np.max(mask2_new)

#mask3
mask3_new = Image.new('I', (1475,1679), 'white')

#mask3 = mask1
mask3_cut = mask1.crop((30 , 0, 1475, 1679))
mask3_new.paste(mask3_cut)
mask3_black = mask_black.crop((1475 -30 , 0, 1475, 1679 ))
mask3_new.paste(mask3_black, [1475 -30, 0])
mask3_new = mask3_new/np.max(mask3_new)


#mask4
mask4_new = Image.new('I', (1475,1679), 'white')

#mask3 = mask1
mask4_cut = mask1.crop((30 , 30, 1475, 1679))
mask4_new.paste(mask4_cut)
mask4_black1 = mask_black.crop((0,  1679 -30 ,1475,1679 ))
mask4_black2 = mask_black.crop((1475 -30 , 0, 1475, 1679 ))

mask4_new.paste(mask4_black1, [0,  1679 -30])
mask4_new.paste(mask4_black2, [1475 -30, 0])
mask4_new = mask4_new/np.max(mask4_new)

img2_new = Image.new('I', (1475, 1679), 'white')
img3_new = Image.new('I', (1475, 1679), 'white')
img4_new = Image.new('I', (1475, 1679), 'white')
    
#Stitch functions
def stitch_4images(infile, infile2, infile3, infile4):

    #load images to data array
    img = Image.open(infile).convert('I') # 'I' : 32-bit integer pixels
    data = np.copy( np.asarray(img) )
    img2 = Image.open(infile2[0]).convert('I') # 'I' : 32-bit integer pixels
    data2 = np.copy( np.asarray(img2) )    
    img3 = Image.open(infile3[0]).convert('I') # 'I' : 32-bit integer pixels
    data3 = np.copy( np.asarray(img3) )    
    img4 = Image.open(infile4[0]).convert('I') # 'I' : 32-bit integer pixels
    data4 = np.copy( np.asarray(img4) )    

    
    #move the data to the original position
    
    img2_cut = img2.crop((0, 30 ,1475, 1679))
    img2_new.paste(img2_cut)
    data2_data = np.copy( np.asarray(img2_new) )
    img3_cut = img3.crop((30, 0 ,1475, 1679))
    img3_new.paste(img3_cut)
    data3_data = np.copy( np.asarray(img3_new) )
    img4_cut = img4.crop((30, 30 ,1475, 1679))
    img4_new.paste(img4_cut)
    data4_data = np.copy( np.asarray(img4_new) )

    #merge masks
    data1_new= data*mask1_data
    data2_new = data2_data*mask2_new
    data3_new= data3_data*mask3_new
    data4_new = data4_data*mask4_new

    
    #data output
    final_data = (data1_new+data2_new+data3_new+data4_new)/(mask1_data+mask2_new+mask3_new+mask4_new)
#    final_data = (data1_new+data2_new+data3_new)/(mask1_data+mask2_new+mask3_new)
#    final_data = (data1_new+data4_new)/(mask1_data+mask4_new)
    
    final_img = Image.fromarray((final_data).astype(np.uint32))

    return final_img    
    
#only two positions for ygaps
def stitch_2images(infile, infile2):

    #load images to data array
    img = Image.open(infile).convert('I') # 'I' : 32-bit integer pixels
    data = np.copy( np.asarray(img) )
    
    if infile2 != []:
        img2 = Image.open(infile2[0]).convert('I') # 'I' : 32-bit integer pixels
#         img2 = Image.open(infile2).convert('I'|) # 'I' : 32-bit integer pixels
        data2 = np.copy( np.asarray(img2) )    

        #move the data to the original position    
        img2_cut = img2.crop((0, 30 ,1475, 1679))
        img2_new.paste(img2_cut)
        data2_data = np.copy( np.asarray(img2_new) )

        #merge masks
        data1_new= data*mask1_data
        data2_new = data2_data*mask2_new

        #data output
        final_data = (data1_new+data2_new)/(mask1_data+mask2_new)
    #    plt.imshow(np.log(final_data), cmap="hot");plt.colorbar();plt.clim(-1, 3)
    else:
        final_data = data*mask1_data

    final_data[np.isnan(final_data)]=-2
    final_img = Image.fromarray((final_data).astype(np.uint32))
#     infile_done = 'stitched/{}_{}.tiff'.format(infile[2:-5],'stitched')
    
#     final_img.save(infile_done)  
    return final_img

def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 

def stitch_2images_folder(folder, infiles=None, interval=1, force=False):
    source_dir = folder + '/saxs/raw/'#'/maxs/raw/'   
    output_dir = folder + '/saxs/stitched/'#'/maxs/stitched/'
    if os.path.isdir(output_dir)==False:
        os.mkdir(output_dir)
    if infiles==None:
        infiles = glob.glob(os.path.join(source_dir, '*pos1*.tiff'))
    else:
        infiles = glob.glob(os.path.join(source_dir, '*{}*pos1*.tiff'.format(infiles)))
    
    infiles.sort()
    processed_count = 0
    error_count = 0
    files_with_errors = ""
    for infile in infiles:
        print(infile)
        infile_filename = infile.split('/')[-1]
        infile_name = infile_filename.split('_')
        infile_name_full = infile_filename.split('_pos1_')
        print(infile_name[-2])
       # print(infile_name)
        for ct, value in enumerate(infile.split('_')):
            if value == 'pos1':
                number = int(infile_name[-2])
                infile2 = glob.glob(os.path.join(source_dir, '{}*pos2*{}*.tiff'.format(infile_name_full[0],str(number+interval) )))
                print("Matched to       :  {}".format(infile2))   
#                 print('TEST: filename = {}'.format(infile_name_full[0]))
                

        if infile2 != []:
            infile_done = output_dir +'{}_{}.tiff'.format(infile_filename[:-5],'stitched')
            if os.path.isfile(infile_done)==False or force==True:
                final_data = stitch_2images(infile, infile2)
                processed_count += 1
                final_data.save(infile_done)
        else:
            files_with_errors += "\r\n"+" {}".format(infile)
            error_count += 1
            #return 
            prRed('Error: The stitching files {} are not valid.'.format(infile))
        
         
        
    print("Processed {} files".format(processed_count))
    print("Errors on  {} files".format(error_count))
    print("    Those errors were on:")
    print(files_with_errors)            

def stitch_2images_folderlist(folder, infiles=None, interval=1, force=False):
    #doesnot care the infile name in pos2 images
    
    source_dir = folder + '/saxs/raw/'#'/maxs/raw/'   
    output_dir = folder + '/saxs/stitched/'#'/maxs/stitched/'

    
    source_dir = folder + '/saxs/raw/'
    output_dir = folder + '/saxs/stitched/'#'/maxs/stitched/'
    if os.path.isdir(output_dir)==False:
        os.mkdir(output_dir)
    if infiles==None:
        infiles = glob.glob(os.path.join(source_dir, '*pos1*.tiff'))
    else:
        infiles = glob.glob(os.path.join(source_dir, '*{}*pos1*.tiff'.format(infiles)))
    
    infiles.sort()
    processed_count = 0
    error_count = 0
    files_with_errors = ""
    for infile in infiles:
        print(infile)
        infile_filename = infile.split('/')[-1]
        infile_name = infile_filename.split('_')
        infile_name_full = infile_filename.split('_pos1_')
        print(infile_name[-2])
       # print(infile_name)
        for ct, value in enumerate(infile.split('_')):
            if value == 'pos1':
                number = int(infile_name[-2])
                infile2 = glob.glob(os.path.join(source_dir, '*pos2*{}*.tiff'.format(str(number+interval) )))
                print("Matched to       :  {}".format(infile2))   
#                 print('TEST: filename = {}'.format(infile_name_full[0]))
                

        if infile2 != []:
            infile_done = output_dir +'{}_{}.tiff'.format(infile_filename[:-5],'stitched')
            if os.path.isfile(infile_done)==False or force==True:
                final_data = stitch_2images(infile, infile2)
                processed_count += 1
                final_data.save(infile_done)
        else:
            files_with_errors += "\r\n"+" {}".format(infile)
            error_count += 1
            #return 
            prRed('Error: The stitching files {} are not valid.'.format(infile))
        
         
        
    print("Processed {} files".format(processed_count))
    print("Errors on  {} files".format(error_count))
    print("    Those errors were on:")
    print(files_with_errors)            
def stitch_4images_folder(folder, infiles=None, interval=1, force=False):
    source_dir = folder + '/saxs/raw/'   
    output_dir = folder + '/saxs/stitched/'
    if os.path.isdir(source_dir)==False:
        return
    
    if os.path.isdir(output_dir)==False:
        os.mkdir(output_dir)

    if infiles==None:
        infiles = glob.glob(os.path.join(source_dir, '*pos1*.tiff'))
    else:
        infiles = glob.glob(os.path.join(source_dir, '*{}*pos1*.tiff'.format(infiles)))

    infiles.sort()
    processed_count = 0
    error_count = 0
    files_with_errors = ""
    
    for infile in infiles:
        print(infile)
        infile_filename = infile.split('/')[-1]
        infile_name = infile_filename.split('_')
        infile_name_full = infile_filename.split('_pos1_')
        print(infile_name[-2])
        for ct, value in enumerate(infile.split('_')):
            if value == 'pos1':
                number = int(infile_name[-2])
                infile2 = glob.glob(os.path.join(source_dir, '{}*pos2*{}*.tiff'.format(infile_name_full[0],str(number+interval*1) )))
                infile3 = glob.glob(os.path.join(source_dir, '{}*pos3*{}*.tiff'.format(infile_name_full[0],str(number+interval*3) )))
                infile4 = glob.glob(os.path.join(source_dir, '{}*pos4*{}*.tiff'.format(infile_name_full[0],str(number+interval*2) )))
                print(infile2)   

        if infile2 != [] and  infile3 != [] and  infile4 != []:
            infile_done = output_dir +'{}_{}.tiff'.format(infile_filename[:-5],'stitched')
            if os.path.isfile(infile_done)==False or force==True:
                final_data = stitch_4images(infile, infile2, infile3, infile4)
                processed_count += 1
                final_data.save(infile_done)
      

        else:
            files_with_errors += "\r\n"+" {}".format(infile)
            error_count += 1
            #return 
            prRed('Error: The stitching files {} are not valid.'.format(infile))
            
def stitch_2images_filelist(folder, infiles=None, interval=1, force=False):
    source_dir = folder + '/saxs/raw/'   
    output_dir = folder + '/saxs/stitched/'
#     output_dir = folder + '/waxs/stitched/2images'

    pos1_filelist = folder + 'SAXS_pos1_list.csv'
    pos2_filelist = folder + 'SAXS_pos2_list.csv'
    if os.path.isdir(output_dir)==False:
        os.mkdir(output_dir)
        
    with open(pos1_filelist) as file:
        pos1_lines = file.readlines()    
    with open(pos2_filelist) as file:
        pos2_lines = file.readlines()    
    
    for ii in range(len(pos2_lines)):
        
        infile = folder+pos1_lines[ii].rstrip()
        infile2 = folder+pos2_lines[ii].rstrip()

        print(infile)
        
        infile_done = output_dir +'{}_{}.tiff'.format(pos1_lines[ii].split('/')[-1].rstrip()[:-5],'stitched')
        if os.path.isfile(infile_done)==False or force==True:
            final_data = stitch_2images(infile, infile2)
#             processed_count += 1
            final_data.save(infile_done) 

            print("Fist data at pos1:  {}".format(infile))   
            print("Matched to       :  {}".format(infile2))   
        else:
            
            print('the file has been generated')

# %% [markdown]
# ##### __Stitch ygap__

# %%
source_dir = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor/'
stitch_2images_folder(folder=source_dir, interval=4)
# Out:
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s1_B_vac_pos1_x0.000_th0.100_5.00s_1335928_saxs.tiff
# 1335928
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s1_B_vac_pos2_x0.000_th0.100_5.00s_1335932_saxs.tiff']
# /tmp/ipykernel_2418615/3622293862.py:113: RuntimeWarning: invalid value encountered in divide
#   final_data = (data1_new+data2_new)/(mask1_data+mask2_new)
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s1_B_vac_pos1_x0.000_th0.150_5.00s_1335929_saxs.tiff
# 1335929
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s1_B_vac_pos2_x0.000_th0.150_5.00s_1335933_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s1_B_vac_pos1_x0.000_th0.200_5.00s_1335930_saxs.tiff
# 1335930
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s1_B_vac_pos2_x0.000_th0.200_5.00s_1335934_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s1_B_vac_pos1_x0.000_th0.300_5.00s_1335931_saxs.tiff
# 1335931
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s1_B_vac_pos2_x0.000_th0.300_5.00s_1335935_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s2_D_vac_pos1_x0.000_th0.100_5.00s_1335950_saxs.tiff
# 1335950
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s2_D_vac_pos2_x0.000_th0.100_5.00s_1335954_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s2_D_vac_pos1_x0.000_th0.150_5.00s_1335951_saxs.tiff
# 1335951
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s2_D_vac_pos2_x0.000_th0.150_5.00s_1335955_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s2_D_vac_pos1_x0.000_th0.200_5.00s_1335952_saxs.tiff
# 1335952
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s2_D_vac_pos2_x0.000_th0.200_5.00s_1335956_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s2_D_vac_pos1_x0.000_th0.300_5.00s_1335953_saxs.tiff
# 1335953
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s2_D_vac_pos2_x0.000_th0.300_5.00s_1335957_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s3_F_vac_pos1_x0.000_th0.100_2.00s_1335969_saxs.tiff
# 1335969
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s3_F_vac_pos2_x0.000_th0.100_2.00s_1335973_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s3_F_vac_pos1_x0.000_th0.150_2.00s_1335970_saxs.tiff
# 1335970
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s3_F_vac_pos2_x0.000_th0.150_2.00s_1335974_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s3_F_vac_pos1_x0.000_th0.200_2.00s_1335971_saxs.tiff
# 1335971
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s3_F_vac_pos2_x0.000_th0.200_2.00s_1335975_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s3_F_vac_pos1_x0.000_th0.300_2.00s_1335972_saxs.tiff
# 1335972
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s3_F_vac_pos2_x0.000_th0.300_2.00s_1335976_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s4_H_vac_pos1_x0.000_th0.100_2.00s_1335994_saxs.tiff
# 1335994
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s4_H_vac_pos2_x0.000_th0.100_2.00s_1335998_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s4_H_vac_pos1_x0.000_th0.150_2.00s_1335995_saxs.tiff
# 1335995
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s4_H_vac_pos2_x0.000_th0.150_2.00s_1335999_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s4_H_vac_pos1_x0.000_th0.200_2.00s_1335996_saxs.tiff
# 1335996
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s4_H_vac_pos2_x0.000_th0.200_2.00s_1336000_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s4_H_vac_pos1_x0.000_th0.300_2.00s_1335997_saxs.tiff
# 1335997
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/DL_s4_H_vac_pos2_x0.000_th0.300_2.00s_1336001_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s1_pristine_vac_pos1_x-0.000_th0.100_5.00s_1335856_saxs.tiff
# 1335856
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s1_pristine_vac_pos2_x-0.000_th0.100_5.00s_1335860_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s1_pristine_vac_pos1_x-0.000_th0.150_5.00s_1335857_saxs.tiff
# 1335857
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s1_pristine_vac_pos2_x-0.000_th0.150_5.00s_1335861_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s1_pristine_vac_pos1_x-0.000_th0.200_5.00s_1335858_saxs.tiff
# 1335858
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s1_pristine_vac_pos2_x-0.000_th0.200_5.00s_1335862_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s1_pristine_vac_pos1_x-0.000_th0.300_5.00s_1335859_saxs.tiff
# 1335859
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s1_pristine_vac_pos2_x-0.000_th0.300_5.00s_1335863_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s2_LiTFSI_vac_pos1_x-0.000_th0.100_5.00s_1335875_saxs.tiff
# 1335875
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s2_LiTFSI_vac_pos2_x-0.000_th0.100_5.00s_1335879_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s2_LiTFSI_vac_pos1_x-0.000_th0.150_5.00s_1335876_saxs.tiff
# 1335876
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s2_LiTFSI_vac_pos2_x0.000_th0.150_5.00s_1335880_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s2_LiTFSI_vac_pos1_x-0.000_th0.200_5.00s_1335877_saxs.tiff
# 1335877
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s2_LiTFSI_vac_pos2_x-0.000_th0.200_5.00s_1335881_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s2_LiTFSI_vac_pos1_x-0.000_th0.300_5.00s_1335878_saxs.tiff
# 1335878
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s2_LiTFSI_vac_pos2_x-0.000_th0.300_5.00s_1335882_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s3_pristine-UV_vac_pos1_x-0.000_th0.100_5.00s_1335894_saxs.tiff
# 1335894
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s3_pristine-UV_vac_pos2_x-0.000_th0.100_5.00s_1335898_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s3_pristine-UV_vac_pos1_x-0.000_th0.150_5.00s_1335895_saxs.tiff
# 1335895
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s3_pristine-UV_vac_pos2_x-0.000_th0.150_5.00s_1335899_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s3_pristine-UV_vac_pos1_x-0.000_th0.200_5.00s_1335896_saxs.tiff
# 1335896
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s3_pristine-UV_vac_pos2_x-0.000_th0.200_5.00s_1335900_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s3_pristine-UV_vac_pos1_x-0.000_th0.300_5.00s_1335897_saxs.tiff
# 1335897
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s3_pristine-UV_vac_pos2_x-0.000_th0.300_5.00s_1335901_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s4_LiTFSI-UV_vac_pos1_x-0.000_th0.100_5.00s_1335911_saxs.tiff
# 1335911
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s4_LiTFSI-UV_vac_pos2_x-0.000_th0.100_5.00s_1335915_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s4_LiTFSI-UV_vac_pos1_x-0.000_th0.150_5.00s_1335912_saxs.tiff
# 1335912
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s4_LiTFSI-UV_vac_pos2_x-0.000_th0.150_5.00s_1335916_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s4_LiTFSI-UV_vac_pos1_x-0.000_th0.200_5.00s_1335913_saxs.tiff
# 1335913
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s4_LiTFSI-UV_vac_pos2_x-0.000_th0.200_5.00s_1335917_saxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s4_LiTFSI-UV_vac_pos1_x-0.000_th0.300_5.00s_1335914_saxs.tiff
# 1335914
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/beamline/ETsai/ATaylor//saxs/raw/SM_s4_LiTFSI-UV_vac_pos2_x-0.000_th0.300_5.00s_1335918_saxs.tiff']
# Processed 32 files
# Errors on  0 files
#     Those errors were on:

# %% [markdown]
# #### &#9642; __Pilatus800k__

# %%
mask_folder = '/nsls2/data/cms/legacy/xf11bm/software/SciAnalysis/SciAnalysis/XSAnalysis/masks/'
mask = mask_folder + 'Dectris/Pilatus800k_gaps-mask.png'
if 0:
    mask_bad = mask_folder + 'NSLSII_11BM_CMS/Pilatus800k_CMS_badpixels-mask.png'


# mask = mask_folder + 'Dectris/Pilatus800_current-mask_extrawideblock.png'

mask1 = Image.open(mask).convert('I') # 'I' : 32-bit integer pixels
mask1_data = np.copy( np.asarray(mask1))
mask1_data = mask1_data/np.max(mask1_data)

mask_black = Image.new('L', (981,1043), 'black')

#mask2
mask2_new = Image.new('I', (981,1043), 'white')

#mask2 = mask1
mask2_cut = mask1.crop((0, 30 ,981, 1043 ))
mask2_new.paste(mask2_cut)
mask2_black = mask_black.crop((0,  1043 -30 ,981,1043 ))
mask2_new.paste(mask2_black, [0,  1043 -30])
mask2_new = mask2_new/np.max(mask2_new)

#mask3
mask3_new = Image.new('I', (981 ,1043), 'white')

#mask3 = mask1
# mask3_cut = mask1.crop((30 , 0, 981, 1043))
# mask3_new.paste(mask3_cut)
# mask3_black = mask_black.crop((981 -30 , 0, 981, 1043 ))
# mask3_new.paste(mask3_black, [981 -30, 0])
# mask3_new = mask3_new/np.max(mask3_new)

mask3_cut = mask1.crop((0 , 0, 981-30, 1043))
mask3_black = mask_black.crop((0 , 0, 30, 1043 ))
mask3_new.paste(mask3_black)
mask3_new.paste(mask3_cut, [30, 0])
mask3_new = mask3_new/np.max(mask3_new)

#mask4
mask4_new = Image.new('I', (981,1043), 'white')

#mask3 = mask1
mask4_cut = mask1.crop((0 , 30, 981-30, 1043))
mask4_black1 = mask_black.crop((0,  1043 -30 ,981,1043 ))
mask4_black2 = mask_black.crop((0 , 0, 30, 1043 ))
mask4_new.paste(mask4_black2)
mask4_new.paste(mask4_black1, [0,  1043 -30])
mask4_new.paste(mask4_cut, [30, 0])
mask4_new = mask4_new/np.max(mask4_new)

img2_new = Image.new('I', (981, 1043), 'white')
img3_new = Image.new('I', (981, 1043), 'white')
img4_new = Image.new('I', (981, 1043), 'white')
    
#Stitch functions
def stitch_4images(infile, infile2, infile3, infile4):

    if infile2 != [] and infile3 != [] and infile4 != []:
        #load images to data array
        img = Image.open(infile).convert('I') # 'I' : 32-bit integer pixels
        data = np.copy( np.asarray(img) )
        img2 = Image.open(infile2[0]).convert('I') # 'I' : 32-bit integer pixels
        data2 = np.copy( np.asarray(img2) )    
        img3 = Image.open(infile3[0]).convert('I') # 'I' : 32-bit integer pixels
        data3 = np.copy( np.asarray(img3) )    
        img4 = Image.open(infile4[0]).convert('I') # 'I' : 32-bit integer pixels
        data4 = np.copy( np.asarray(img4) )    

        #move the data to the original position

        img2_cut = img2.crop((0, 30 ,981, 1043))
        img2_new.paste(img2_cut)
        data2_data = np.copy( np.asarray(img2_new) )
        img3_cut = img3.crop((0, 0 ,981-30, 1043))
        img3_black = mask_black.crop((0 , 0, 30, 1043 ))
        img3_new.paste(img3_black)
        img3_new.paste(img3_cut, [30, 0])
        data3_data = np.copy( np.asarray(img3_new) )

        img4_cut = img4.crop((0, 30 ,981-30, 1043))
        img4_black1 = mask_black.crop((0,  1043-30 ,981, 1043 ))
        img4_black2 = mask_black.crop((0 , 0, 30, 1043 ))
        img4_new.paste(img4_black2)
        img4_new.paste(img4_black1, [0,  1043 -30])
        img4_new.paste(img4_cut, [30, 0])
        data4_data = np.copy( np.asarray(img4_new) )

        #merge masks
        data1_new= data*mask1_data
        data2_new = data2_data*mask2_new
        data3_new= data3_data*mask3_new
        data4_new = data4_data*mask4_new


        #data output
        final_data = (data1_new+data2_new+data3_new+data4_new)/(mask1_data+mask2_new+mask3_new+mask4_new)
    #     final_data = (data1_new+data2_new+data3_new)/(mask1_data+mask2_new+mask3_new)
    #     final_data = (data1_new+data4_new)/(mask1_data+mask4_new)

    #    plt.imshow(np.log(final_data), cmap="hot");plt.colorbar();plt.clim(-1, 3)
#     else:
#         final_data = data*mask1_data
    
    final_data[np.isnan(final_data)]=-2
    final_img = Image.fromarray((final_data).astype(np.uint32))
    return final_img
    
def stitch_3images(infile, infile2, infile3):

    if infile2 != [] and infile3 != [] :
        #load images to data array
        img = Image.open(infile).convert('I') # 'I' : 32-bit integer pixels
        data = np.copy( np.asarray(img) )
        img2 = Image.open(infile2[0]).convert('I') # 'I' : 32-bit integer pixels
        data2 = np.copy( np.asarray(img2) )    
        img3 = Image.open(infile3[0]).convert('I') # 'I' : 32-bit integer pixels
        data3 = np.copy( np.asarray(img3) )    
#         img4 = Image.open(infile4[0]).convert('I') # 'I' : 32-bit integer pixels
#         data4 = np.copy( np.asarray(img4) )    

        #move the data to the original position

        img2_cut = img2.crop((0, 30 ,981, 1043))
        img2_new.paste(img2_cut)
        data2_data = np.copy( np.asarray(img2_new) )
        img3_cut = img3.crop((0, 0 ,981-30, 1043))
        img3_black = mask_black.crop((0 , 0, 30, 1043 ))
        img3_new.paste(img3_black)
        img3_new.paste(img3_cut, [30, 0])
        data3_data = np.copy( np.asarray(img3_new) )

#         img4_cut = img4.crop((0, 30 ,981-30, 1043))
#         img4_black1 = mask_black.crop((0,  1043-30 ,981, 1043 ))
#         img4_black2 = mask_black.crop((0 , 0, 30, 1043 ))
#         img4_new.paste(img4_black2)
#         img4_new.paste(img4_black1, [0,  1043 -30])
#         img4_new.paste(img4_cut, [30, 0])
#         data4_data = np.copy( np.asarray(img4_new) )

        #merge masks
        data1_new= data*mask1_data
        data2_new = data2_data*mask2_new
        data3_new= data3_data*mask3_new
#         data4_new = data4_data*mask4_new


        #data output
        final_data = (data1_new+data2_new+data3_new)/(mask1_data+mask2_new+mask3_new)
    #     final_data = (data1_new+data2_new+data3_new)/(mask1_data+mask2_new+mask3_new)
    #     final_data = (data1_new+data4_new)/(mask1_data+mask4_new)

    #    plt.imshow(np.log(final_data), cmap="hot");plt.colorbar();plt.clim(-1, 3)
#     else:
#         final_data = data*mask1_data
    
    final_data[np.isnan(final_data)]=-2
    final_img = Image.fromarray((final_data).astype(np.uint32))
    return final_img

#only two positions for ygaps
def stitch_2images(infile, infile2, show_region=False):

    if type(infile)==list:
        infile = infile[0]
    if type(infile2)==list:
        infile2 = infile2[0]
    #load images to data array
    img = Image.open(infile).convert('I') # 'I' : 32-bit integer pixels
    data = np.copy( np.asarray(img) )
    if infile2 != []:
        img2 = Image.open(infile2).convert('I') # 'I' : 32-bit integer pixels
        data2 = np.copy( np.asarray(img2) )    

        #move the data to the original position    
        img2_cut = img2.crop((0, 30 ,981, 1043))
        img2_new.paste(img2_cut)
        data2_data = np.copy( np.asarray(img2_new) )

        #merge masks
        data1_new= data*mask1_data
        data2_new = data2_data*mask2_new

        #data output
        final_data = (data1_new+data2_new)/(mask1_data+mask2_new)
    else:
        final_data = data*mask1_data

    final_data[np.isnan(final_data)]=-2
    
    if show_region==True:
        ax1 = plt.subplot(221)
        ax2 = plt.subplot(222)
        ax3 = plt.subplot(223)
        ax1 = plt.imshow(np.log(final_data), cmap="hot");plt.colorbar();plt.clim(-1, 3)
        ax2 = plt.imshow(np.log(data2_data), cmap="hot");plt.colorbar();plt.clim(-1, 3)
        ax3 = plt.imshow(np.log(data), cmap="hot");plt.colorbar();plt.clim(-1, 3)
    
    final_img = Image.fromarray((final_data).astype(np.uint32))
    return final_img

def stitch_4images_folder(folder, infiles=None, interval=1, overwrite=False):
    source_dir = folder + '/waxs/raw/'   
    output_dir = folder + '/waxs/stitched/'
#     output_dir = folder + '/waxs/stitched/'
    if os.path.isdir(output_dir)==False:
        os.mkdir(output_dir)

    if infiles==None:
        infiles = glob.glob(os.path.join(source_dir, '*pos1*.tiff'))
    else:
        infiles = glob.glob(os.path.join(source_dir, '*{}*pos1*.tiff'.format(infiles)))
    infiles.sort()
    processed_count = 0
    error_count = 0
    files_with_errors = ""
    for infile in infiles:
        print(infile)
        infile_filename = infile.split('/')[-1]
        infile_name = infile_filename.split('_')
        #print(infile_name)
        for ct, value in enumerate(infile.split('_')):
            if value == 'pos1':
                number = int(infile_name[-2])
                infile2 = glob.glob(os.path.join(source_dir, '{}*pos2*{}*.tiff'.format(infile_name[0],str(number+interval*1) )))
                infile3 = glob.glob(os.path.join(source_dir, '{}*pos3*{}*.tiff'.format(infile_name[0],str(number+interval*3) )))
                infile4 = glob.glob(os.path.join(source_dir, '{}*pos4*{}*.tiff'.format(infile_name[0],str(number+interval*2) )))
                print(infile2)   

        if infile2 != [] and  infile3 != [] and  infile4 != []:
            #final_data = test_stitch_2images(infile, infile2)#, infile3, infile4)
            final_data = stitch_4images(infile, infile2, infile3, infile4)
            processed_count += 1
            infile_done = output_dir +'{}_{}.tiff'.format(infile_filename[:-5],'stitched')
            
#             if infile_done is valid:
#                 overwrite==True
            final_data.save(infile_done) 
        else:
            files_with_errors += "\r\n"+" {}".format(infile)
            error_count += 1
            #return 
            prRed('Error: The stitching files {} are not valid.'.format(infile))
#         infile_done = output_dir + '{}_{}.tiff'.format(infile_filename[:-5],'stitched')
#         final_data.save(infile_done)    

def stitch_3images_folder(folder, infiles=None, interval=1):
    source_dir = folder  + '/waxs/raw/'    
    output_dir = folder + '/waxs/stitched/3images'
#     output_dir = folder + '/waxs/stitched/'
    if os.path.isdir(output_dir)==False:
        os.mkdir(output_dir)

    if infiles==None:
        infiles = glob.glob(os.path.join(source_dir, '*pos1*.tiff'))
    else:
        infiles = glob.glob(os.path.join(source_dir, '*{}*pos1*.tiff'.format(infiles)))
    infiles.sort()
    processed_count = 0
    error_count = 0
    files_with_errors = ""
    for infile in infiles:
        print(infile)
        infile_filename = infile.split('/')[-1]
        infile_name = infile_filename.split('_')
        #print(infile_name)
        for ct, value in enumerate(infile.split('_')):
            if value == 'pos1':
                number = int(infile_name[-2])
                infile2 = glob.glob(os.path.join(source_dir, '{}*pos2*{}*.tiff'.format(infile_name[0],str(number+interval*1) )))
                infile3 = glob.glob(os.path.join(source_dir, '{}*pos3*{}*.tiff'.format(infile_name[0],str(number+interval*2) )))
#                 infile4 = glob.glob(os.path.join(source_dir, '{}*pos4*{}*.tiff'.format(infile_name[0],str(number+2) )))
                print(infile2)   

        if infile2 != [] and  infile3 != []:
            #final_data = test_stitch_2images(infile, infile2)#, infile3, infile4)
            final_data = stitch_3images(infile, infile2, infile3)
            processed_count += 1
            infile_done = output_dir +'{}_{}.tiff'.format(infile_filename[:-5],'stitched')
            final_data.save(infile_done) 
            
        else:
            files_with_errors += "\r\n"+" {}".format(infile)
            error_count += 1
            #return 
            prRed('Error: The stitching files {} are not valid.'.format(infile))

#         infile_done = output_dir + '{}_{}.tiff'.format(infile_filename[:-5],'stitched')
#         final_data.save(infile_done)   

def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 

#stitched data at fixed interval, doesnot match the file names
def stitch_2images_folder_brutal(folder, infiles=None, interval=1, force=False):
    source_dir = folder + '/waxs/raw/'   
    output_dir = folder + '/waxs/stitched/'
#     output_dir = folder + '/waxs/stitched/2images'
    if os.path.isdir(output_dir)==False:
        os.mkdir(output_dir)
    if infiles==None:
        infiles = glob.glob(os.path.join(source_dir, '*pos1*.tiff'))
    else:
        infiles = glob.glob(os.path.join(source_dir, '*{}*pos1*.tiff'.format(infiles)))
    
    infiles.sort()
    processed_count = 0
    error_count = 0
    files_with_errors = ""
    for infile in infiles:
        print(infile)
        infile_filename = infile.split('/')[-1]
        infile_name = infile_filename.split('_')
        infile_name_full = infile_filename.split('_pos1_')
        print(infile_name[-2])
       # print(infile_name)
        for ct, value in enumerate(infile.split('_')):
            if value == 'pos1':
                number = int(infile_name[-2])
                infile2 = glob.glob(os.path.join(source_dir, '*pos2*{}*.tiff'.format(str(number+interval) )))
                print("Matched to       :  {}".format(infile2))   

        if infile2 != []:
            
            infile_done = output_dir +'{}_{}.tiff'.format(infile_filename[:-5],'stitched')
            if os.path.isfile(infile_done)==False or force==True:
                final_data = stitch_2images(infile, infile2)
                processed_count += 1
                final_data.save(infile_done) 
            else:
                print('the file has been generated')
        
        else:
            files_with_errors += "\r\n"+" {}".format(infile)
            error_count += 1
            #return 
            prRed('Error: The stitching files {} are not valid.'.format(infile))
        
        
# #     print("Processed {} files".format(processed_count))
#     print("Errors on  {} files".format(error_count))
#     print("    Those errors were on:")
#     print(files_with_errors)
    

    
def stitch_2images_folder(folder, det='waxs', infiles=None, match_th=1, interval=1, force=False):
    source_dir = folder + '/' + det+ '/raw/'   
    output_dir = folder + '/' + det+ '/stitched/'
#     output_dir = folder + '/waxs/stitched/2images'
    if os.path.isdir(output_dir)==False:
        os.mkdir(output_dir)
    if infiles==None:
        infiles = glob.glob(os.path.join(source_dir, '*pos1*.tiff'))
    else:
        infiles = glob.glob(os.path.join(source_dir, '*{}*pos1*.tiff'.format(infiles)))
    
    infiles.sort()
    processed_count = 0
    error_count = 0
    files_with_errors = ""
    for infile in infiles:
        print(infile)
        infile_filename = infile.split('/')[-1]
        infile_name = infile_filename.split('_')
        infile_name_full = infile_filename.split('_pos1_')
        print(infile_name[-2])
        if match_th == 1:
            x = infile.split('_th')
            th = float(x[1].split('_')[0])
            print(th)
            
       # print(infile_name)
        for ct, value in enumerate(infile.split('_')):
            if value == 'pos1':
                number = int(infile_name[-2])
                if match_th==1:
                    infile2 = glob.glob(os.path.join(source_dir, '{}*pos2*{}*{}*.tiff'.format(infile_name_full[0],th,str(number+interval) )))
                else:
                    infile2 = glob.glob(os.path.join(source_dir, '{}*pos2*{}*.tiff'.format(infile_name_full[0],str(number+interval) )))
                print("Matched to       :  {}".format(infile2))   

        if infile2 != []:
            
            infile_done = output_dir +'{}_{}.tiff'.format(infile_filename[:-5],'stitched')
            if os.path.isfile(infile_done)==False or force==True:
                final_data = stitch_2images(infile, infile2)
                processed_count += 1
                final_data.save(infile_done) 
            else:
                print('the file has been generated')
        
        else:
            files_with_errors += "\r\n"+" {}".format(infile)
            error_count += 1
            #return 
            prRed('Error: The stitching files {} are not valid.'.format(infile))
        
        
    print("Processed {} files".format(processed_count))
    print("Errors on  {} files".format(error_count))
    print("    Those errors were on:")
    print(files_with_errors)


    #load two filelists, by default names as 'WAXS_pos1_list.csv' and 'WAXS_pos2_list.csv'
def stitch_2images_filelist(folder, infiles=None, interval=1, force=False):
    source_dir = folder + '/waxs/raw/'   
    output_dir = folder + '/waxs/stitched/'
#     output_dir = folder + '/waxs/stitched/2images'

    pos1_filelist = folder + 'WAXS_pos1_list.csv'
    pos2_filelist = folder + 'WAXS_pos2_list.csv'
    if os.path.isdir(output_dir)==False:
        os.mkdir(output_dir)
        
    with open(pos1_filelist) as file:
        pos1_lines = file.readlines()    
    with open(pos2_filelist) as file:
        pos2_lines = file.readlines()    
    
    for ii in range(len(pos2_lines)):
        
        infile = folder+pos1_lines[ii].rstrip()
        infile2 = folder+pos2_lines[ii].rstrip()

        infile_done = output_dir +'{}_{}.tiff'.format(pos1_lines[ii].split('/')[-1].rstrip()[:-5],'stitched')
        if os.path.isfile(infile_done)==False or force==True:
            final_data = stitch_2images(infile, infile2)
#             processed_count += 1
            final_data.save(infile_done) 

            print("Fist data at pos1:  {}".format(infile))   
            print("Matched to       :  {}".format(infile2))   
        else:
            
            print('the file has been generated')
        
        
        
        
#     print("Processed {} files".format(processed_count))
#     print("Errors on  {} files".format(error_count))
#     print("    Those errors were on:")
#     print(files_with_errors)
    
    
def stitch_2images_folder_pos2(folder, infiles=None, interval=1, force=False):
    source_dir = folder + '/waxs/raw/'   
    output_dir = folder + '/waxs/stitched/'
#     output_dir = folder + '/waxs/stitched/2images'
    if os.path.isdir(output_dir)==False:
        os.mkdir(output_dir)
    if infiles==None:
        infiles = glob.glob(os.path.join(source_dir, '*pos2*.tiff'))
    else:
        infiles = glob.glob(os.path.join(source_dir, '*{}*pos2*.tiff'.format(infiles)))
    
    infiles.sort()
    processed_count = 0
    error_count = 0
    files_with_errors = ""
    for infile in infiles:
        print(infile)
        infile_filename = infile.split('/')[-1]
        infile_name = infile_filename.split('_')
        infile_name_full = infile_filename.split('_pos2_')
        print(infile_name[-2])
       # print(infile_name)
        for ct, value in enumerate(infile.split('_')):
            if value == 'pos2':
                number = int(infile_name[-2])
                infile1 = glob.glob(os.path.join(source_dir, '{}*pos1*{}*.tiff'.format(infile_name_full[0],str(number-interval) )))
                 

        if infile1 != []:
            
            infile_done = output_dir +'{}_{}.tiff'.format(infile_filename[:-5],'stitched')
            print("Matched to       :  {}".format(infile1))  
            print("Stitched to       :  {}".format(infile_done))  
            print(infile1)
            print(infile)
            if os.path.isfile(infile_done)==False or force==True:
                final_data = stitch_2images(infile1, infile)
                processed_count += 1
                final_data.save(infile_done) 
            else:
                print('the file has been generated')
        
        else:
            files_with_errors += "\r\n"+" {}".format(infile)
            error_count += 1
            #return 
            prRed('Error: The stitching files {} are not valid.'.format(infile))
        
        
    print("Processed {} files".format(processed_count))
    print("Errors on  {} files".format(error_count))
    print("    Those errors were on:")
    print(files_with_errors)
    
    
def search_file(folder, infile, det='waxs'):
    source_dir = folder + '/' + det+ '/raw/' 
    infile = glob.glob(os.path.join(source_dir, '*{}*pos1*.tiff'.format(infile)))    
    infiles.sort()
    
    return 


def amend(infile1, infile2, crop_box=(600, 580 ,900, 700)):

    if infile1 != [] and infile2 != []:
        #load images to data array
        img = Image.open(infile1).convert('I') # 'I' : 32-bit integer pixels
        img2 = Image.open(infile2).convert('I') # 'I' : 32-bit integer pixels

        region = img2.crop(crop_box)
#         region = 0
        img.paste(region, crop_box)
        data = np.copy( np.asarray(img) )
    
    data[np.isnan(data)]=-2
    final_img = Image.fromarray((data).astype(np.uint32))
    return final_img


def amend_folder(folder, infiles=None):
    folder1 = folder + '/waxs/stitched/'   
    folder2 = folder + '/waxs/stitched_1/'   
    output_dir = folder + '/waxs/stitched_final/'
#     output_dir = folder + '/waxs/stitched/2images'

    source_dir = folder1
    source_dir2 = folder2
    
    if os.path.isdir(output_dir)==False:
        os.mkdir(output_dir)
    if infiles==None:
        infiles = glob.glob(os.path.join(source_dir, '*stitched*.tiff'))
    else:
        infiles = glob.glob(os.path.join(source_dir, '*{}*stitched*.tiff'.format(infiles)))
    
    infiles.sort()
    processed_count = 0
    error_count = 0
    files_with_errors = ""
    for infile in infiles:

        infile_filename = infile.split('/')[-1]

        infile2 = glob.glob(os.path.join(source_dir2, infile_filename ))

        print(infile)
        print(infile2)
        
#         print("Matched to       :  {}".format(infile1))   
#         print("Matched to       :  {}".format(infile2))   

        if infile2 != []:
            final_data = amend(infile, infile2[0])
            processed_count += 1
            infile_done = output_dir +'{}'.format(infile_filename)
            final_data.save(infile_done) 
        
        else:
            files_with_errors += "\r\n"+" {}".format(infile)
            error_count += 1
            #return 
            prRed('Error: The stitching files {} are not valid.'.format(infile))
        
        
    print("Processed {} files".format(processed_count))
    print("Errors on  {} files".format(error_count))
    print("    Those errors were on:")
    print(files_with_errors)

# %%
type(mask1)
# Out:
# PIL.Image.Image

# %% [markdown]
# ##### __Stitch ygap__

# %%
source_dir = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo2/'
stitch_2images_folder(folder=source_dir, det='waxs', interval=3, match_th=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[154], line 2
#       1 source_dir = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/*/'
# ----> 2 stitch_2images_folder(folder=source_dir, interval=10, match_th=1)
#
# Cell In[152], line 352, in stitch_2images_folder(folder, det, infiles, match_th, interval, force)
#     350 #     output_dir = folder + '/waxs/stitched/2images'
#     351     if os.path.isdir(output_dir)==False:
# --> 352         os.mkdir(output_dir)
#     353     if infiles==None:
#     354         infiles = glob.glob(os.path.join(source_dir, '*pos1*.tiff'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/*//waxs/stitched/'

# %%
samples = ['EW_PbI2_air_hum0_run6_4V', 
           'EW_PbI2_air_hum25_run1', 'EW_PbI2_air_hum25_run2', 
           'EW_PbI2_air_hum50_run2',
           'EW_PbI2_N2_hum0_run1',
           'EW_PbI2_N2_hum25_run1', 
           'EW_PbI2_N2_hum50_run1', 'EW_PbI2_N2_hum50_run2',           
          ] 

samples = ['EW_FAI0_PbI20_hum25_air_run1',
           'EW_FAI0_PbI20_hum50_air_run1', 'EW_FAI0_PbI250_hum0_air_run1',  'EW_FAI0_PbI250_hum50_air_run1',
           'EW_FAI0_PbI20_hum0_N2_run1',  'EW_FAI0_PbI250_hum0_N2_run1', 
           
           'EW_FAI0_PbI20_hum0_air_run2',
           'EW_FAI0_PbI20_hum0_air_run3', 
           'EW_FAI0_PbI20_hum0_air_run4',
           'EW_FAI0_PbI20_hum0_air_run5',
           'EW_FAI0_PbI20_hum0_air_run6',
           'EW_FAI0_PbI20_hum0_N2_run2',
           'EW_FAI0_PbI220_hum0_N2_run1',        
                    
          ]

USER_DIR = '/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/'

for sample in samples:
    print("====={}=====".format(sample))
    source_dir = USER_DIR + sample + '/'
    stitch_2images_folder(folder=source_dir, det='maxs', interval=10, match_th=1)
# Out:
# =====EW_FAI0_PbI20_hum25_air_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_1033.4s_RH22.631_x-0.001_th0.050_5.00s_1343078_maxs.tiff
# 1343078
# 0.05
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos2_1107.6s_RH21.463_x-0.001_th0.050_5.00s_1343088_maxs.tiff']
# /tmp/ipykernel_1969090/3069341738.py:186: RuntimeWarning: invalid value encountered in divide
#   final_data = (data1_new+data2_new)/(mask1_data+mask2_new)
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_1041.3s_RH22.063_x-0.001_th0.100_5.00s_1343079_maxs.tiff
# 1343079
# 0.1
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos2_1114.7s_RH22.168_x-0.001_th0.100_5.00s_1343089_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_1048.3s_RH22.158_x-0.001_th0.150_5.00s_1343080_maxs.tiff
# 1343080
# 0.15
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos2_1121.6s_RH17.656_x-0.001_th0.150_5.00s_1343090_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_1056.4s_RH22.894_x-0.001_th0.200_5.00s_1343081_maxs.tiff
# 1343081
# 0.2
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos2_1128.8s_RH20.874_x-0.001_th0.200_5.00s_1343091_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_1063.8s_RH23.262_x-0.001_th0.250_5.00s_1343082_maxs.tiff
# 1343082
# 0.25
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos2_1135.7s_RH21.442_x-0.001_th0.250_5.00s_1343092_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_1070.8s_RH22.494_x-0.001_th0.300_5.00s_1343083_maxs.tiff
# 1343083
# 0.3
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos2_1142.8s_RH21.674_x-0.001_th0.300_5.00s_1343093_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_1078.1s_RH22.252_x-0.001_th0.350_5.00s_1343084_maxs.tiff
# 1343084
# 0.35
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos2_1150.1s_RH21.979_x-0.001_th0.350_5.00s_1343094_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_1084.9s_RH22.305_x-0.001_th0.400_5.00s_1343085_maxs.tiff
# 1343085
# 0.4
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos2_1157.0s_RH21.937_x-0.001_th0.400_5.00s_1343095_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_1091.8s_RH22.494_x-0.001_th0.450_5.00s_1343086_maxs.tiff
# 1343086
# 0.45
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos2_1164.2s_RH19.907_x-0.001_th0.450_5.00s_1343096_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_1098.7s_RH21.453_x-0.001_th0.500_5.00s_1343087_maxs.tiff
# 1343087
# 0.5
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos2_1171.2s_RH20.180_x-0.001_th0.500_5.00s_1343097_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_970.9s_RH22.862_x-0.001_th0.300_1.00s_1343074_maxs.tiff
# 1343074
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_970.9s_RH22.862_x-0.001_th0.300_1.00s_1343074_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_980.7s_RH23.777_x2.002_th0.300_1.00s_1343076_maxs.tiff
# 1343076
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_980.7s_RH23.777_x2.002_th0.300_1.00s_1343076_maxs.tiff are not valid.
# Processed 10 files
# Errors on  2 files
#     Those errors were on:
#
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_970.9s_RH22.862_x-0.001_th0.300_1.00s_1343074_maxs.tiff
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum25_air_run1//maxs/raw/EW_FAI0_PbI20_hum25_air_run1_static_pos1_980.7s_RH23.777_x2.002_th0.300_1.00s_1343076_maxs.tiff
# =====EW_FAI0_PbI20_hum50_air_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_864.8s_RH51.070_x-0.001_th0.300_1.00s_1343112_maxs.tiff
# 1343112
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_864.8s_RH51.070_x-0.001_th0.300_1.00s_1343112_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_874.4s_RH52.006_x2.001_th0.300_1.00s_1343114_maxs.tiff
# 1343114
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_874.4s_RH52.006_x2.001_th0.300_1.00s_1343114_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_913.6s_RH50.354_x-0.001_th0.050_5.00s_1343116_maxs.tiff
# 1343116
# 0.05
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos2_987.3s_RH50.228_x-0.001_th0.050_5.00s_1343126_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_921.8s_RH50.870_x-0.001_th0.100_5.00s_1343117_maxs.tiff
# 1343117
# 0.1
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos2_994.0s_RH51.091_x-0.001_th0.100_5.00s_1343127_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_928.9s_RH51.091_x-0.001_th0.150_5.00s_1343118_maxs.tiff
# 1343118
# 0.15
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos2_1001.1s_RH50.323_x-0.001_th0.150_5.00s_1343128_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_935.7s_RH51.133_x-0.001_th0.200_5.00s_1343119_maxs.tiff
# 1343119
# 0.2
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos2_1008.1s_RH50.954_x-0.001_th0.200_5.00s_1343129_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_943.1s_RH50.744_x-0.001_th0.250_5.00s_1343120_maxs.tiff
# 1343120
# 0.25
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos2_1015.0s_RH50.880_x-0.001_th0.250_5.00s_1343130_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_950.1s_RH50.007_x-0.001_th0.300_5.00s_1343121_maxs.tiff
# 1343121
# 0.3
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos2_1022.2s_RH50.680_x-0.001_th0.300_5.00s_1343131_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_956.9s_RH50.733_x-0.001_th0.350_5.00s_1343122_maxs.tiff
# 1343122
# 0.35
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos2_1029.1s_RH50.228_x-0.001_th0.350_5.00s_1343132_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_964.1s_RH50.260_x-0.001_th0.400_5.00s_1343123_maxs.tiff
# 1343123
# 0.4
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos2_1036.1s_RH50.544_x-0.001_th0.400_5.00s_1343133_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_971.2s_RH52.637_x-0.001_th0.450_5.00s_1343124_maxs.tiff
# 1343124
# 0.45
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos2_1043.2s_RH50.849_x-0.001_th0.450_5.00s_1343134_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_978.3s_RH51.543_x-0.001_th0.500_5.00s_1343125_maxs.tiff
# 1343125
# 0.5
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos2_1050.2s_RH51.164_x-0.001_th0.500_5.00s_1343135_maxs.tiff']
# Processed 10 files
# Errors on  2 files
#     Those errors were on:
#
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_864.8s_RH51.070_x-0.001_th0.300_1.00s_1343112_maxs.tiff
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum50_air_run1//maxs/raw/EW_FAI0_PbI20_hum50_air_run1_static_pos1_874.4s_RH52.006_x2.001_th0.300_1.00s_1343114_maxs.tiff
# =====EW_FAI0_PbI250_hum0_air_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_596.6s_RH1.807_x-0.001_th0.300_1.00s_1343150_maxs.tiff
# 1343150
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_596.6s_RH1.807_x-0.001_th0.300_1.00s_1343150_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_606.7s_RH1.028_x2.001_th0.300_1.00s_1343152_maxs.tiff
# 1343152
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_606.7s_RH1.028_x2.001_th0.300_1.00s_1343152_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_633.4s_RH1.207_x-0.001_th0.050_5.00s_1343154_maxs.tiff
# 1343154
# 0.05
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos2_706.8s_RH0.755_x-0.001_th0.050_5.00s_1343164_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_641.9s_RH1.891_x-0.001_th0.100_5.00s_1343155_maxs.tiff
# 1343155
# 0.1
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos2_713.9s_RH1.249_x-0.001_th0.100_5.00s_1343165_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_648.9s_RH1.459_x-0.001_th0.150_5.00s_1343156_maxs.tiff
# 1343156
# 0.15
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos2_720.7s_RH1.428_x-0.001_th0.150_5.00s_1343166_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_656.0s_RH3.584_x-0.001_th0.200_5.00s_1343157_maxs.tiff
# 1343157
# 0.2
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos2_727.7s_RH2.185_x-0.001_th0.200_5.00s_1343167_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_663.1s_RH1.533_x-0.001_th0.250_5.00s_1343158_maxs.tiff
# 1343158
# 0.25
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos2_734.7s_RH2.048_x-0.001_th0.250_5.00s_1343168_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_670.2s_RH0.723_x-0.001_th0.300_5.00s_1343159_maxs.tiff
# 1343159
# 0.3
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos2_741.7s_RH1.607_x-0.001_th0.300_5.00s_1343169_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_677.1s_RH1.281_x-0.001_th0.350_5.00s_1343160_maxs.tiff
# 1343160
# 0.35
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos2_748.7s_RH1.533_x-0.001_th0.350_5.00s_1343170_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_683.9s_RH1.722_x-0.001_th0.400_5.00s_1343161_maxs.tiff
# 1343161
# 0.4
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos2_755.6s_RH1.649_x-0.001_th0.400_5.00s_1343171_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_690.7s_RH1.523_x-0.001_th0.450_5.00s_1343162_maxs.tiff
# 1343162
# 0.45
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos2_762.7s_RH2.574_x-0.001_th0.450_5.00s_1343172_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_697.7s_RH0.955_x-0.001_th0.500_5.00s_1343163_maxs.tiff
# 1343163
# 0.5
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos2_769.7s_RH1.323_x-0.001_th0.500_5.00s_1343173_maxs.tiff']
# Processed 10 files
# Errors on  2 files
#     Those errors were on:
#
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_596.6s_RH1.807_x-0.001_th0.300_1.00s_1343150_maxs.tiff
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_air_run1//maxs/raw/EW_FAI0_PbI250_hum0_air_run1_static_pos1_606.7s_RH1.028_x2.001_th0.300_1.00s_1343152_maxs.tiff
# =====EW_FAI0_PbI250_hum50_air_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_641.9s_RH51.795_x-0.001_th0.300_1.00s_1343188_maxs.tiff
# 1343188
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_641.9s_RH51.795_x-0.001_th0.300_1.00s_1343188_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_651.8s_RH51.059_x2.002_th0.300_1.00s_1343190_maxs.tiff
# 1343190
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_651.8s_RH51.059_x2.002_th0.300_1.00s_1343190_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_675.9s_RH50.765_x-0.001_th0.050_5.00s_1343192_maxs.tiff
# 1343192
# 0.05
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos2_749.2s_RH50.954_x-0.001_th0.050_5.00s_1343202_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_683.9s_RH51.133_x-0.001_th0.100_5.00s_1343193_maxs.tiff
# 1343193
# 0.1
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos2_756.4s_RH51.806_x-0.001_th0.100_5.00s_1343203_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_690.8s_RH51.290_x-0.001_th0.150_5.00s_1343194_maxs.tiff
# 1343194
# 0.15
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos2_763.4s_RH51.911_x-0.001_th0.150_5.00s_1343204_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_697.9s_RH51.711_x-0.001_th0.200_5.00s_1343195_maxs.tiff
# 1343195
# 0.2
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos2_770.2s_RH50.933_x-0.001_th0.200_5.00s_1343205_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_704.8s_RH53.289_x-0.001_th0.250_5.00s_1343196_maxs.tiff
# 1343196
# 0.25
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos2_777.2s_RH51.585_x-0.001_th0.250_5.00s_1343206_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_712.0s_RH51.501_x-0.001_th0.300_5.00s_1343197_maxs.tiff
# 1343197
# 0.3
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos2_784.1s_RH52.037_x-0.001_th0.300_5.00s_1343207_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_719.2s_RH51.038_x-0.001_th0.350_5.00s_1343198_maxs.tiff
# 1343198
# 0.35
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos2_791.4s_RH51.206_x-0.001_th0.350_5.00s_1343208_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_726.1s_RH50.912_x-0.001_th0.400_5.00s_1343199_maxs.tiff
# 1343199
# 0.4
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos2_798.5s_RH50.586_x-0.001_th0.400_5.00s_1343209_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_733.2s_RH52.353_x-0.001_th0.450_5.00s_1343200_maxs.tiff
# 1343200
# 0.45
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos2_805.4s_RH51.680_x-0.001_th0.450_5.00s_1343210_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_740.1s_RH50.796_x-0.001_th0.500_5.00s_1343201_maxs.tiff
# 1343201
# 0.5
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos2_812.5s_RH50.828_x-0.001_th0.500_5.00s_1343211_maxs.tiff']
# Processed 10 files
# Errors on  2 files
#     Those errors were on:
#
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_641.9s_RH51.795_x-0.001_th0.300_1.00s_1343188_maxs.tiff
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum50_air_run1//maxs/raw/EW_FAI0_PbI250_hum50_air_run1_static_pos1_651.8s_RH51.059_x2.002_th0.300_1.00s_1343190_maxs.tiff
# =====EW_FAI0_PbI20_hum0_N2_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_601.3s_RH2.154_x-0.001_th0.300_1.00s_1343226_maxs.tiff
# 1343226
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_601.3s_RH2.154_x-0.001_th0.300_1.00s_1343226_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_611.6s_RH2.006_x2.002_th0.300_1.00s_1343228_maxs.tiff
# 1343228
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_611.6s_RH2.006_x2.002_th0.300_1.00s_1343228_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_632.7s_RH1.638_x-0.001_th0.050_5.00s_1343230_maxs.tiff
# 1343230
# 0.05
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos2_705.9s_RH2.185_x-0.001_th0.050_5.00s_1343240_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_640.8s_RH1.260_x-0.001_th0.100_5.00s_1343231_maxs.tiff
# 1343231
# 0.1
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos2_713.0s_RH1.533_x-0.001_th0.100_5.00s_1343241_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_647.8s_RH0.828_x-0.001_th0.150_5.00s_1343232_maxs.tiff
# 1343232
# 0.15
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos2_720.3s_RH1.764_x-0.001_th0.150_5.00s_1343242_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_654.7s_RH2.101_x-0.001_th0.200_5.00s_1343233_maxs.tiff
# 1343233
# 0.2
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos2_727.3s_RH2.206_x-0.001_th0.200_5.00s_1343243_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_661.6s_RH3.058_x-0.001_th0.250_5.00s_1343234_maxs.tiff
# 1343234
# 0.25
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos2_734.5s_RH0.681_x-0.001_th0.250_5.00s_1343244_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_668.9s_RH1.838_x-0.001_th0.300_5.00s_1343235_maxs.tiff
# 1343235
# 0.3
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos2_741.3s_RH1.028_x-0.001_th0.300_5.00s_1343245_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_675.7s_RH1.123_x-0.001_th0.350_5.00s_1343236_maxs.tiff
# 1343236
# 0.35
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos2_748.3s_RH0.555_x-0.001_th0.350_5.00s_1343246_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_682.8s_RH2.795_x-0.001_th0.400_5.00s_1343237_maxs.tiff
# 1343237
# 0.4
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos2_755.4s_RH1.638_x-0.001_th0.400_5.00s_1343247_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_689.7s_RH1.859_x-0.001_th0.450_5.00s_1343238_maxs.tiff
# 1343238
# 0.45
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos2_762.6s_RH1.701_x-0.001_th0.450_5.00s_1343248_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_696.9s_RH1.785_x-0.001_th0.500_5.00s_1343239_maxs.tiff
# 1343239
# 0.5
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos2_769.6s_RH2.217_x-0.001_th0.500_5.00s_1343249_maxs.tiff']
# Processed 10 files
# Errors on  2 files
#     Those errors were on:
#
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_601.3s_RH2.154_x-0.001_th0.300_1.00s_1343226_maxs.tiff
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_N2_run1//maxs/raw/EW_FAI0_PbI20_hum0_N2_run1_static_pos1_611.6s_RH2.006_x2.002_th0.300_1.00s_1343228_maxs.tiff
# =====EW_FAI0_PbI250_hum0_N2_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_584.2s_RH1.218_x-0.001_th0.300_1.00s_1343264_maxs.tiff
# 1343264
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_584.2s_RH1.218_x-0.001_th0.300_1.00s_1343264_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_594.2s_RH1.270_x2.001_th0.300_1.00s_1343266_maxs.tiff
# 1343266
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_594.2s_RH1.270_x2.001_th0.300_1.00s_1343266_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_622.2s_RH1.070_x-0.001_th0.050_5.00s_1343268_maxs.tiff
# 1343268
# 0.05
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos2_694.5s_RH1.291_x-0.001_th0.050_5.00s_1343278_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_630.0s_RH1.565_x-0.001_th0.100_5.00s_1343269_maxs.tiff
# 1343269
# 0.1
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos2_701.8s_RH1.586_x-0.001_th0.100_5.00s_1343279_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_636.9s_RH0.955_x-0.001_th0.150_5.00s_1343270_maxs.tiff
# 1343270
# 0.15
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos2_708.8s_RH1.049_x-0.001_th0.150_5.00s_1343280_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_643.8s_RH2.732_x-0.001_th0.200_5.00s_1343271_maxs.tiff
# 1343271
# 0.2
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos2_715.7s_RH1.838_x-0.001_th0.200_5.00s_1343281_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_650.6s_RH3.321_x-0.001_th0.250_5.00s_1343272_maxs.tiff
# 1343272
# 0.25
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos2_722.6s_RH1.260_x-0.001_th0.250_5.00s_1343282_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_657.5s_RH0.439_x-0.001_th0.300_5.00s_1343273_maxs.tiff
# 1343273
# 0.3
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos2_730.0s_RH1.554_x-0.001_th0.300_5.00s_1343283_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_664.9s_RH0.923_x-0.001_th0.350_5.00s_1343274_maxs.tiff
# 1343274
# 0.35
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos2_736.9s_RH1.039_x-0.001_th0.350_5.00s_1343284_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_672.0s_RH1.985_x-0.001_th0.400_5.00s_1343275_maxs.tiff
# 1343275
# 0.4
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos2_743.8s_RH0.639_x-0.001_th0.400_5.00s_1343285_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_678.8s_RH1.680_x-0.001_th0.450_5.00s_1343276_maxs.tiff
# 1343276
# 0.45
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos2_750.8s_RH0.650_x-0.001_th0.450_5.00s_1343286_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_685.6s_RH1.491_x-0.001_th0.500_5.00s_1343277_maxs.tiff
# 1343277
# 0.5
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos2_757.8s_RH1.785_x-0.001_th0.500_5.00s_1343287_maxs.tiff']
# Processed 10 files
# Errors on  2 files
#     Those errors were on:
#
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_584.2s_RH1.218_x-0.001_th0.300_1.00s_1343264_maxs.tiff
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI250_hum0_N2_run1//maxs/raw/EW_FAI0_PbI250_hum0_N2_run1_static_pos1_594.2s_RH1.270_x2.001_th0.300_1.00s_1343266_maxs.tiff
# =====EW_FAI0_PbI20_hum0_air_run2=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_649.8s_RH1.438_x-0.001_th0.300_1.00s_1343304_maxs.tiff
# 1343304
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_649.8s_RH1.438_x-0.001_th0.300_1.00s_1343304_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_660.3s_RH0.587_x2.000_th0.300_1.00s_1343306_maxs.tiff
# 1343306
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_660.3s_RH0.587_x2.000_th0.300_1.00s_1343306_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_682.7s_RH2.206_x-0.001_th0.050_5.00s_1343308_maxs.tiff
# 1343308
# 0.05
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos2_756.9s_RH1.396_x-0.001_th0.050_5.00s_1343318_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_690.7s_RH0.513_x-0.001_th0.100_5.00s_1343309_maxs.tiff
# 1343309
# 0.1
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos2_764.0s_RH1.565_x-0.001_th0.100_5.00s_1343319_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_697.8s_RH0.618_x-0.001_th0.150_5.00s_1343310_maxs.tiff
# 1343310
# 0.15
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos2_771.0s_RH1.533_x-0.001_th0.150_5.00s_1343320_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_704.9s_RH1.491_x-0.001_th0.200_5.00s_1343311_maxs.tiff
# 1343311
# 0.2
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos2_778.0s_RH1.649_x-0.001_th0.200_5.00s_1343321_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_712.3s_RH0.134_x-0.001_th0.250_5.00s_1343312_maxs.tiff
# 1343312
# 0.25
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos2_785.2s_RH1.586_x-0.001_th0.250_5.00s_1343322_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_719.4s_RH2.417_x-0.001_th0.300_5.00s_1343313_maxs.tiff
# 1343313
# 0.3
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos2_792.3s_RH1.239_x-0.001_th0.300_5.00s_1343323_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_726.7s_RH1.901_x-0.001_th0.350_5.00s_1343314_maxs.tiff
# 1343314
# 0.35
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos2_799.7s_RH1.617_x-0.001_th0.350_5.00s_1343324_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_733.7s_RH2.048_x-0.001_th0.400_5.00s_1343315_maxs.tiff
# 1343315
# 0.4
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos2_806.5s_RH1.291_x-0.001_th0.400_5.00s_1343325_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_740.8s_RH0.544_x-0.001_th0.450_5.00s_1343316_maxs.tiff
# 1343316
# 0.45
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos2_813.4s_RH1.365_x-0.001_th0.450_5.00s_1343326_maxs.tiff']
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_747.8s_RH2.017_x-0.001_th0.500_5.00s_1343317_maxs.tiff
# 1343317
# 0.5
# Matched to       :  ['/nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos2_820.3s_RH0.639_x-0.001_th0.500_5.00s_1343327_maxs.tiff']
# Processed 10 files
# Errors on  2 files
#     Those errors were on:
#
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_649.8s_RH1.438_x-0.001_th0.300_1.00s_1343304_maxs.tiff
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run2//maxs/raw/EW_FAI0_PbI20_hum0_air_run2_static_pos1_660.3s_RH0.587_x2.000_th0.300_1.00s_1343306_maxs.tiff
# =====EW_FAI0_PbI20_hum0_air_run3=====
# Processed 0 files
# Errors on  0 files
#     Those errors were on:
#
# =====EW_FAI0_PbI20_hum0_air_run4=====
# Processed 0 files
# Errors on  0 files
#     Those errors were on:
#
# =====EW_FAI0_PbI20_hum0_air_run5=====
# Processed 0 files
# Errors on  0 files
#     Those errors were on:
#
# =====EW_FAI0_PbI20_hum0_air_run6=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run6//maxs/raw/EW_FAI0_PbI20_hum0_air_run6_static_pos1_604.2s_RH0.324_x-0.001_th0.300_1.00s_1343382_maxs.tiff
# 1343382
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run6//maxs/raw/EW_FAI0_PbI20_hum0_air_run6_static_pos1_604.2s_RH0.324_x-0.001_th0.300_1.00s_1343382_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run6//maxs/raw/EW_FAI0_PbI20_hum0_air_run6_static_pos1_614.0s_RH2.143_x2.001_th0.300_1.00s_1343384_maxs.tiff
# 1343384
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run6//maxs/raw/EW_FAI0_PbI20_hum0_air_run6_static_pos1_614.0s_RH2.143_x2.001_th0.300_1.00s_1343384_maxs.tiff are not valid.
# Processed 0 files
# Errors on  2 files
#     Those errors were on:
#
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run6//maxs/raw/EW_FAI0_PbI20_hum0_air_run6_static_pos1_604.2s_RH0.324_x-0.001_th0.300_1.00s_1343382_maxs.tiff
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI20_hum0_air_run6//maxs/raw/EW_FAI0_PbI20_hum0_air_run6_static_pos1_614.0s_RH2.143_x2.001_th0.300_1.00s_1343384_maxs.tiff
# =====EW_FAI0_PbI20_hum0_N2_run2=====
# Processed 0 files
# Errors on  0 files
#     Those errors were on:
#
# =====EW_FAI0_PbI220_hum0_N2_run1=====
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI220_hum0_N2_run1//maxs/raw/EW_FAI0_PbI220_hum0_N2_run1_static_pos1_645.6s_RH1.638_x-0.001_th0.300_1.00s_1343416_maxs.tiff
# 1343416
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI220_hum0_N2_run1//maxs/raw/EW_FAI0_PbI220_hum0_N2_run1_static_pos1_645.6s_RH1.638_x-0.001_th0.300_1.00s_1343416_maxs.tiff are not valid.
# /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI220_hum0_N2_run1//maxs/raw/EW_FAI0_PbI220_hum0_N2_run1_static_pos1_655.1s_RH0.986_x2.001_th0.300_1.00s_1343418_maxs.tiff
# 1343418
# 0.3
# Matched to       :  []
#  Error: The stitching files /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI220_hum0_N2_run1//maxs/raw/EW_FAI0_PbI220_hum0_N2_run1_static_pos1_655.1s_RH0.986_x2.001_th0.300_1.00s_1343418_maxs.tiff are not valid.
# Processed 0 files
# Errors on  2 files
#     Those errors were on:
#
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI220_hum0_N2_run1//maxs/raw/EW_FAI0_PbI220_hum0_N2_run1_static_pos1_645.6s_RH1.638_x-0.001_th0.300_1.00s_1343416_maxs.tiff
#  /nsls2/data/cms/legacy/xf11bm/data/2024_1/LLoo/EW_FAI0_PbI220_hum0_N2_run1//maxs/raw/EW_FAI0_PbI220_hum0_N2_run1_static_pos1_655.1s_RH0.986_x2.001_th0.300_1.00s_1343418_maxs.tiff

# %% [markdown]
# # &#9635; Supplementary

# %% [markdown]
#  ## S1. Background subtraction
#
#  Same as Sections 0 and 3, except we specify background in __load_args__:
#
#  - 'background' can be (1) a raw TIFF, (2) one float value, or (3) an np.ndarray
#
#  - 'transmission_int' can be (1) the transmission CSV file under ./data/, or (2) one float value

# %%
# Experimental parameters
########################################
calibration = Calibration(wavelength_A=0.9184) # 13.5 keV
#calibration = Calibration(wavelength_A=0.9184) # 13.5 keV
calibration.set_image_size(1475, height=1679) # Pilatus2M
calibration.set_pixel_size(pixel_size_um=172.0)
calibration.set_beam_position(738.0, 1679-593 ) # SAXSx -60, SAXSy -73

calibration.set_distance(2.0) # 5m

mask_dir = SciAnalysis_PATH + '/SciAnalysis/XSAnalysis/masks/'
mask = Mask(mask_dir+'Dectris/Pilatus2M_gaps-mask.png')
mask.load(EXPR_DIR+'saxs/analysis/Pilatus2M_current-mask_Kap.png')

# Files to analyze
########################################
#EXPR_DIR = '/nsls2/data/cms/legacy/xf11bm/data/2020_2/CKe/saxs/'
EXPR_DIR = '/nsls2/data/cms/legacy/xf11bm/data/2022_2/Exxon3/'

source_dir = EXPR_DIR + 'saxs/raw/'
output_dir = EXPR_DIR + 'saxs/analysis_test/'

pattern = 'MG*492830*'  

infiles = glob.glob(os.path.join(source_dir, pattern+'.tiff'))
infiles.sort()


# Analysis to perform
########################################
load_args = { 'calibration' : calibration, 
             'mask' : mask,
             #'background' : '/nsls2/data/cms/legacy/xf11bm/data/2020_2/CKe2/saxs/raw/'+'*0130*tiff',
             'background' : EXPR_DIR+'/saxs/raw/MG_empty_BKG_x0.000_y0.000_10.00s_492839_saxs.tiff',
             #'background' : 100,
             'transmission_int': EXPR_DIR+'/data/Transmission_output.csv', # Can also specify an float value, eg 1.4
             }

run_args = { 'verbosity' : 3,
            'rcParams': {'axes.labelsize': 25, 
                         'xtick.labelsize': 20, 'ytick.labelsize': 20, 
                         'xtick.major.pad': 10, 'ytick.major.pad': 10, },
            }
process = Protocols.ProcessorXS(load_args=load_args, run_args=run_args)

protocols = [
    Protocols.circular_average(name='circular_average', ylog=True, plot_range=[0, 4.0, 5, None], gridlines=True, label_filename=True)  , #'csv'   
    Protocols.q_image(blur=None, colorbar=True, save_results=['npz'], plot_buffers = [0.1, 0.1, 0.1, 0.1], transparent=False, label_filename=True) ,     
    ]


# Run
########################################
t0 = time.time()

infiles = glob.glob(os.path.join(source_dir, pattern+'.tiff')); 
infiles.sort()    
print('Processing {} infiles...'.format(len(infiles)))
process.run(infiles, protocols, output_dir=output_dir, force = 1)
print('Process Time: {:.1f} min'.format((time.time()-t0)/60))


#---------
# process.load(infiles[0], **load_args)
# data = process.handle_calibration(infile, **load_args)
# process.handle_background(data, **load_args)

# %% [markdown]
# #### __Show before/after__

# %%
import imageio

## Load images
#filename = 'CKe_S5_24k_4vac_x0.100_y-0.200_20.00s_2790326_saxs'
filename = 'MG_19-110924-1_virgin_KapCap2mm_x-0.000_y0.000_10.00s_492830_saxs'

infile0 = output_dir+'q_image/' + filename + '.png'
infile1 = output_dir+'q_image/' + filename + '_rmbkg.png'
img0 = imageio.imread(infile0)
img1 = imageio.imread(infile1)


## Plot
plt.figure()
plt.rcParams['figure.figsize'] = [10, 10] #[height, width] of the figure

plt.subplot(2,2,1)
plt.imshow(img0); plt.title('Original')
plt.subplot(2,2,2)
plt.imshow(img1); plt.title('Background removed')

plt.show()


## Load 1D
infile0 = output_dir+'circular_average/' + filename + '.dat'
infile1 = output_dir+'circular_average/' + filename + '_rmbkg.dat'
line0 = np.loadtxt(infile0)
line1 = np.loadtxt(infile1)

## Plot
plt.subplot(2,2,3)
plt.plot(line0[:,0], np.log10(line0[:,2])); plt.grid()
plt.subplot(2,2,4)
plt.plot(line1[:,0], np.log10(line1[:,2])); plt.grid()

plt.show()

# %%
import re, difflib
import pandas as pd

infile = EXPR_DIR+'/data/Transmission_output.csv'
df = pd.read_csv(infile)
#print(df)

filelist = df['b_scanID']

b = filelist.isin([492809])
print(b)

# %% [markdown]
# ## __S2. Load results and plot__

# %% [markdown]
# #### &#9642; __Load DAT__

# %%
### Load 1D data
output_dir = '/nsls2/data/cms/legacy/xf11bm/data/2023_1/beamline/ETsai/saxs/analysis/circular_average/'
fn = 'SA_static_7AX_vac_x-0.000_y0.000_5.00s_988713_saxs.dat'
infile = output_dir+fn
print(infile)

infile_background = output_dir+'Empty_vac_x0.000_y0.000_1.00s_988712_saxs.dat'
print(infile_background)

if 0:  ## Load from analysis output .DAT
    line = DataLine(infile) 
    
else:  ## General loading
    data = np.loadtxt(infile)
    line = DataLine(x = data[:,0], y = data[:,1])
    st = "q range = [{:.3f}, {:.3f}] A^-1".format(np.min(line.x), np.max(line.x))
    print(st)

    data = np.loadtxt(infile_background)
    line_bg = DataLine(x = data[:,0], y = data[:,1])
    st = "q range = [{:.3f}, {:.3f}] A^-1".format(np.min(line.x), np.max(line.x))
    print(st)


### Corrected data
ratio = np.max(line_bg.y)/np.max(line.y)
ratio = (line_bg.y[0])/(line.y[0])
ratio = 1
print("ratio = {}".format(ratio))

line_corrected = DataLine(x = line_bg.x, y = line.y*ratio - line_bg.y)



### Plot
# %matplotlib inline
# %matplotlib auto
plt.figure(20, figsize=(10, 10)); plt.clf()
plt.subplot(2,2,1)
plt.plot( np.log10(line.x), np.log10(line.y), 'b', linewidth=1, label=line.name)
plt.title(fn)
plt.grid()
plt.xlabel('A^-1')

plt.subplot(2,2,2)
plt.plot(line_bg.x, np.log10(line_bg.y), 'b', linewidth=1, label=line.name)
plt.title('background')
plt.grid()


plt.subplot(2,2,3)
plt.plot(np.log10(line_corrected.x), np.log10(line_corrected.y), 'b', linewidth=1, label=line.name)
plt.title('(data*{:.4f} - background)'.format(ratio))
plt.grid()

# %% [markdown]
# #### &#9642; __Load NPZ__

# %%
output_dir = '/nsls2/data/cms/legacy/xf11bm/data/2022_3/RHeadrick3/waxs/analysis/'
infile = output_dir+'q_image/B6_N3_Trans3_map_vac_x-0.006_y-1.050_2.00s_763448_waxs.npz'
print(infile)

data = np.load(infile)
#print(list(data))

image = data['image']
x_axis = data['x_axis']
y_axis = data['y_axis']
x_scale = data['x_scale']
y_scale = data['y_scale']


##### Can plot in log or not; Adjust cmap for colormap, clim for plot range
plt.figure(); 
plt.pcolormesh(x_axis, y_axis, np.log(image), cmap='viridis') #plot in log intensity

plt.colorbar()
plt.clim([0, 6])

[qx, qz] = [0.48, 2.175]
[dqx, dqz] = [0.02, 0.02]
plt.plot([qx-dqx, qx+dqx], [qz-dqz, qz-dqz], 'r-')
plt.plot([qx-dqx, qx+dqx], [qz+dqz, qz+dqz], 'r-')
plt.plot([qx-dqx, qx-dqx], [qz-dqz, qz+dqz], 'r-')
plt.plot([qx+dqx, qx+dqx], [qz-dqz, qz+dqz], 'r-')

print([qx, qz] /x_scale)
plt.title(infile)

# %% [markdown]
# #### &#9642; __Extract analysis results from .XML to .TXT to .NPY__

# %%
## Functions for extracting results from xml files
########################################
from SciAnalysis.Result import * # Results() object
def extract_results(infiles, extractions, outfile, verbosity=3):
    if verbosity>=3: print("Extracting results for {} infiles...".format(len(infiles)))   
    results = Results().extract_multi_save_txt(outfile, infiles, extractions, verbosity=verbosity)
    
    return results

def load_file(infile, verbosity=3):
    if verbosity>=3:
        print(" Loading data from file: {}".format(infile))
    
    with open(infile, 'r') as fin:
        names = fin.readline().split()
        lines = fin.readlines()

    if verbosity>=4:
        print('  Saved data has {} columns:'.format(len(names)))
        print(names)
        
    return names, lines


# Files to analyze
########################################
EXPR_DIR = '/nsls2/data/cms/legacy/xf11bm/data/2021_2/SSenanayak/waxs/'
verbosity = 3

source_dir = EXPR_DIR + 'stitched_analysis_test/'
output_dir = EXPR_DIR + 'stitched_analysis_test/'

pattern = 'NT' 

## Extract results from XML files
results_dir = source_dir + 'results/' # Location of xml files
infiles = glob.glob(os.path.join(results_dir, '{}*.xml'.format(pattern)))
outfile = os.path.join(output_dir, '{}-extracted.txt'.format(pattern))


extractions = [ #[ 'metadata_extract', ['x_position', 'y_position', 'sequence_ID', 'anneal_time'] ] ,
            ['circular_fit_compare3', ['fit_peaks_prefactor1', 'fit_peaks_x_center1', 'fit_peaks_sigma1', 'fit_peaks_chi_squared', 'fit_peaks_d0', 'fit_peaks_grain_size' ] ],
            ]    

## Takes XML and output to outfile (TXT)
results = extract_results(infiles, extractions, outfile=outfile, verbosity=verbosity)


## Export TXT to NPY
names, lines = load_file(outfile, verbosity=verbosity)

columns = [
    #'metadata_extract__x_position', 
    #'metadata_extract__y_position', 
    #'metadata_extract__anneal_time',
    'circular_fit_compare3__fit_peaks_chi_squared'
    ]

indices = [names.index(col) for col in columns]

data = []
for i, line in enumerate(lines):
    line = line.split()
    if len(line)>=len(indices):
        row = [ float(line[i]) for i in indices ]
        data.append(row)

print('\n----- Output array:\n {}'.format(data))
        
## Save 
if 0: 
    outfile = os.path.join(output_dir, '{}-{:d}.npy'.format(pattern, len(data)))
    np.save(outfile, data)
    if verbosity>=3:
        print('  Saved data as'.format(outfile))

# %% [markdown]
# #### &#9642; __Load ROI__

# %%
import pandas as pd

## Get infile
pattern = 'B6_N3_Trans3_map_vac_x-0.006_y-1.050_2.00s_763448_waxs'
infiles = glob.glob(os.path.join(output_dir+'/roi/', pattern+'*.txt')); 
print('Plotting {} infiles...'.format(len(infiles)))

## Load 
stats_list = []
for nn, infile in enumerate(infiles):
    data =  pd.read_table(infile, delimiter = ' ', header=None)
    if nn==0: print(data)
        
    temp = []
    for ii in np.arange(3,13):
        temp.append(data[2][ii])
    stats_list.append(temp)

    
stats_array = np.asarray(stats_list)


## Plot 
#%matplotlib tk
plt.rcParams['figure.figsize'] = [10, 5] #[height, width] of the figure

for ii in np.arange(0,stats_array.shape[1]):
    plt.plot(stats_array[:,ii])

# %% [markdown]
# ## S3. ROI trend

# %%
load_args = { 'calibration' : calibration, 
             #'mask' : mask,
             #'rot180' : False,
             #'flip' : True, # PSCCD
             }
run_args = { 'verbosity' : 3,
            #'save_results' : ['xml', 'plots', 'txt', 'hdf5'],
            }
process = Protocols.ProcessorXS(load_args=load_args, run_args=run_args)

ii = 0
det = exp.dict['expinfo']['det']
folder = exp.dict['expinfo']['folder']

infile_fullpath = folder+'/'+det+'/raw/'+exp.dict['rawinfo']['filename'][ii]+'_'+det+'.tiff'
data = process.load(infile_fullpath, calibration=calibration, mask=mask, run_args=run_args)

plt.figure(1, figsize=(12,5)); plt.clf()


##1 
if 0: #Si
    roi_x = [55-20, 105]
    roi_y = [470-20, 520]

#roi_x = [710-5, 760-5]
#roi_y = [310, 330]

##2 
if 1: #BTBT
    roi_x = [650, 700]
    roi_y = [570, 620]

    
##3
if 0: #Au, Ag
    roi_x = [550, 650]
    roi_y = [130, 180]

    
if 0: # SAXS direct beam
    roi_x = [700, 820]
    roi_y = [1050, 1100]
    
    
#plt.imshow(np.log10(data.data), cmap='jet', vmin=0.5, vmax=3.5); plt.colorbar()
plt.imshow((data.data), cmap='jet'); plt.colorbar()
plt.plot([roi_x[0],roi_x[0]],[roi_y[0],roi_y[1]],'k-')
plt.plot([roi_x[0],roi_x[1]],[roi_y[0],roi_y[0]],'k-')
plt.plot([roi_x[1],roi_x[1]],[roi_y[0],roi_y[1]],'k-')
plt.plot([roi_x[0],roi_x[1]],[roi_y[1],roi_y[1]],'k-')

plt.title(exp.dict['rawinfo']['filename'][ii])

#print(np.sum(data.data[roi_y[0]:roi_y[1], roi_x[0]:roi_x[1]]))

# %% [markdown]
# ### Get ROI for infiles

# %%
roi_val = []
roi_val.append([])
x_pos = []

count = -1
x_prev = 0

for ii, infile in enumerate(infiles):
    if np.mod(ii+1, 100)==0: print('[{:.0f}%]'.format(ii/Nfiles*100))

    det = exp.dict['expinfo']['det']
    folder = exp.dict['expinfo']['folder']

    infile_fullpath = folder+'/'+det+'/raw/'+exp.dict['rawinfo']['filename'][ii]+'_'+det+'.tiff'
    data = process.load(infile_fullpath, calibration=calibration, mask=mask, run_args=run_args)

    x_now = float(exp.dict['rawinfo']['filename'][ii].split('x')[1].split('_')[0])
    
    if np.abs(x_now - x_prev)>1e-6:  
        x_pos.append(x_now)
        x_prev = x_now
        #print('new pos')
        
        count = count+1      
        roi_val.append([])
    
    val = np.sum(data.data[roi_y[0]:roi_y[1], roi_x[0]:roi_x[1]])
    roi_val[count].append(val)
    

print('Done!')

# %% [markdown]
# ### Plot lines

# %%
Nx = len(roi_val)
print(Nx)
cmap = mpl.colormaps['jet'] #viridis, jet, hsv, brg
colors = cmap(np.linspace(0.0, 1.0, Nx))

plt.figure(figsize=(16,8))
for ii in np.arange(0, Nx-1):

    plt.plot(roi_val[ii][::1] + ii*np.mean(roi_val[0])*0.02, color=colors[ii], marker='.')
    plt.text(-10, roi_val[ii][0] + (ii)*np.mean(roi_val[0])*0.02, 'x='+str(x_pos[ii]))
    if len(roi_val[ii])<120:
        print('short')
        roi_val.pop(ii)

#plt.plot(roi2_val,'r.-')

plt.title(exp.dict['rawinfo']['filename'][0]+'\n (N={})'.format(len(roi_val[0])))
#plt.legend(['x1', 'x0', 'x-1'])
#print(roi_val)
print(exp.dict['rawinfo']['filename'][0])

# %% [markdown]
# # The End
